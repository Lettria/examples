# %% [markdown]
# #### Extract document text chunks

# %%
import requests

api_host = 'https://api.lettria.com'
api_route = api_host + '/parse'
document_file_name = 'file.txt'
document_file_location = './data/'
jwt_token_file = 'jwt_token.txt'
jwt_token = open(jwt_token_file, 'r').read().strip()

with open(document_file_location + document_file_name, 'rb') as file:
    response = requests.post(
        api_route,
        files=[('file', ( document_file_name, file, "application/text"))],
        headers={"Authorization":"LettriaProKey " + jwt_token}
    ).json()
text_chunks = [chunk['content'] for chunk in response['chunks'] if chunk['type'] == 'text']
print(text_chunks)
# Out:
# ['In the domain of our ontology, we define various classes such as Departments, Employees, External, Human_Resource, Intern, Internal, International, Junior, Local, Manager, Marketing, Office, Operations, and Senior.', "We establish relationships using object properties like 'has,' 'have,' 'is_a_kind_of,' 'is_a_part_of,' 'sub-departments,' and 'types.' Additionally, we utilize data properties such as 'createdON,' 'depID,' 'empContact,' 'empID,' 'empName,' and 'joinedON.'", 'Individuals are instances of classes, and we have named individuals like Harry, Hina, Sina, Tara, delhi_branch, france_branch, mumbai_branch, and opcore.', 'Examples of class assertions include stating that Harry is a Senior, Hina is a Junior, Sina is a Manager, Tara is an Intern, delhi_branch is Local, france_branch is International, mumbai_branch is Human_Resource, and opcore is Operations.', "We assert data property values for individuals, like Harry's employee contact, ID, name, and joining date. Similar assertions are made for other individuals.", 'Our ontology specifies the hierarchy of classes, stating that External is a type of Operations, Human_Resource is a type of Departments, Intern is a type of Employees, Internal is a type of Operations, International is a type of Marketing, Junior is a type of Employees, Local is a type of Marketing, Manager is a type of Employees, Marketing is a type of Departments, Operations is a type of Departments, and Senior is a type of Employees.', 'We also express relationships between classes, such as stating that External departments are part of the Operations department, Human Resource departments are part of the overall Departments, and Sub-departments are equivalent to being a part of departments.', "Object properties like 'has' connect Offices with Departments, 'have' connects Departments with Employees, 'is_a_kind_of' connects Departments with their types, 'is_a_part_of' connects Marketing with its sub-departments, 'sub-departments' connects Operations with its sub-departments, and 'types' connects Employees with their types.", "Data properties like 'createdON' are associated with the creation date of Departments, 'depID' is associated with the department ID of Departments, 'empContact' is associated with the contact number of Employees, 'empID' is associated with the employee ID of Employees, 'empName' is associated with the name of Employees, and 'joinedON' is associated with the joining date of Employees.", 'This abstracted text aims to capture the essence of our RDF ontology, providing a foundation for structuring and understanding the relationships within the data.']

# %% [markdown]
# #### Text to graph using Lettria structuration endpoint

# %%
api_route = api_host + '/structuration'

response = requests.post(
    api_route,
    json={
        "documents": text_chunks,
        "options":{
            "rdf_export": True
        }
    },
    headers={"Authorization":"LettriaProKey " + jwt_token}
).json()

rdf_string = response['rdf']
print(rdf_string)
# Out:
# @prefix card: <https://data.lettria.com/card/> .
# @prefix d: <https://doc.lettria.com/ontology/1.0/Data/> .
# @prefix info: <https://data.lettria.com/info/> .
# @prefix l: <https://doc.lettria.com/ontology/1.0/> .
# @prefix m: <https://doc.lettria.com/ontology/1.0/Metadata/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# info:29c14695-1a65-45bc-a817-5568a2e1383f a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "kind" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:73|0:74|0:76" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "369:379|380:382|385:389" ;
#     m:temporality "present" ;
#     m:uniqueId "29c14695-1a65-45bc-a817-5568a2e1383f|1702738161.0001326" .
#
# <https://data.lettria.com/project/63369e3f175cea0024662887> a l:Project ;
#     rdfs:label "63369e3f175cea0024662887" ;
#     l:Document <https://data.lettria.com/document/63369e3f175cea0024662887_document_0>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_1>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_2>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_3>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_4>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_5>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_6>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_7>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_8>,
#         <https://data.lettria.com/document/63369e3f175cea0024662887_document_9> ;
#     m:platformUrl "https://app.lettria.com/nlp/project/view/63369e3f175cea0024662887/overview" ;
#     m:projectId "63369e3f175cea0024662887" .
#
# card:04c82808-5189-4577-a6f3-87319886cbae a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'have'" ;
#     l:Event info:701d2d6e-e501-41b1-afa9-622a745b86da ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:10" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "63:69" ;
#     m:uniqueId "04c82808-5189-4577-a6f3-87319886cbae|1702738160.9217434" .
#
# card:0630a095-6251-4af1-b0a5-d7c240427b52 a owl:Class,
#         l:Card ;
#     l:Attribute info:cb6823a3-4d6e-44be-8faa-c4b9b32a45b2 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|language|code" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "code",
#         "communication_element",
#         "language",
#         "mean_of_expression" ;
#     d:finestCategosens "code" ;
#     d:lemma "'empcontact'" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:24" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "148:160" ;
#     m:uniqueId "0630a095-6251-4af1-b0a5-d7c240427b52|1702738160.9300277" .
#
# card:06e0876d-1f0c-4226-aa97-f7b5deda8c1b a owl:Class,
#         l:Card ;
#     l:Attribute info:ae1fd9e0-dea1-41c4-b961-bb32f0ebcf6d ;
#     d:categopath "characteristic_jj|other_characteristic" ;
#     d:categosens "characteristic_jj",
#         "other_characteristic" ;
#     d:finestCategosens "other_characteristic" ;
#     d:lemma "internal" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:31" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "168:176" ;
#     m:uniqueId "06e0876d-1f0c-4226-aa97-f7b5deda8c1b|1702738160.9032273" .
#
# card:0be1b1b4-dd8a-41d2-a675-a88403741db3 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:6e7e5e56-0ce3-4cad-8ba9-73d4087d837a ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:7" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "31:33" ;
#     m:uniqueId "0be1b1b4-dd8a-41d2-a675-a88403741db3|1702738160.810671" .
#
# card:13a3886a-0c09-47aa-9d5d-324260bef93e a owl:Class,
#         l:Card ;
#     l:Attribute info:b60590e4-3de9-42c5-b23c-68792bd18350,
#         info:c3a79364-c600-4fcb-89fb-d7af45a825e5 ;
#     d:categopath "abstract_thing|[features]|attribute" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "attribute" ;
#     d:finestCategosens "attribute" ;
#     d:lemma "property" ;
#     l:Link info:99bf7223-3425-4cf8-97bd-2240af522955 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:1" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "5:15" ;
#     m:uniqueId "13a3886a-0c09-47aa-9d5d-324260bef93e|1702738160.9302633" .
#
# card:152e5908-cce1-4130-b71c-ea69a95ed575 a owl:Class,
#         l:Card ;
#     l:Attribute info:13000ff3-6cab-4f68-8873-d27e8322478b ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|[person_by_relationship]|person_by_other_relationship" ;
#     d:categosens "[person_by_characteristics]",
#         "[person_by_relationship]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_other_relationship" ;
#     d:finestCategosens "person_by_other_relationship" ;
#     d:lemma "employee" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:11" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "61:69" ;
#     m:uniqueId "152e5908-cce1-4130-b71c-ea69a95ed575|1702738160.8356643" .
#
# card:17c87fe2-86ad-4eed-ac35-ed2221fbd7be a owl:Class,
#         l:Card ;
#     d:lemma "GHOST_CARD" ;
#     l:Event info:1027c2bd-d22a-4631-abf1-16b97548ca9c,
#         info:5d8b71d9-f4d0-45c0-8af4-a3c39ca5f80f,
#         info:a80d85ed-6d88-4dd5-8e61-8d07c8145507,
#         info:b5a89d41-7a4b-478a-8f84-953c3383ca5e,
#         info:e744befe-c086-46df-9fae-93c9f95e2b75 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "" ;
#     m:uniqueId "17c87fe2-86ad-4eed-ac35-ed2221fbd7be|1702738160.9381368" .
#
# card:1b09f8e8-42c5-4fe2-aa3b-c0a7cf85f366 a owl:Class,
#         l:Card ;
#     l:Attribute info:a4b71784-a2ae-4f1a-8f16-e3bc4f439e40 ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|[person_by_relationship]|person_by_other_relationship" ;
#     d:categosens "[person_by_characteristics]",
#         "[person_by_relationship]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_other_relationship" ;
#     d:finestCategosens "person_by_other_relationship" ;
#     d:lemma "employee" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:64" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "322:331" ;
#     m:uniqueId "1b09f8e8-42c5-4fe2-aa3b-c0a7cf85f366|1702738160.9029558" .
#
# card:1ca8d583-6ed5-4bba-aafb-7ce6f9bd2cf2 a owl:Class,
#         l:Card ;
#     l:Attribute info:61abd483-b312-4914-a37b-ce2623aff409 ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|[person_by_relationship]|person_by_other_relationship" ;
#     d:categosens "[person_by_characteristics]",
#         "[person_by_relationship]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_other_relationship" ;
#     d:finestCategosens "person_by_other_relationship" ;
#     d:lemma "employee" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:29" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "157:166" ;
#     m:uniqueId "1ca8d583-6ed5-4bba-aafb-7ce6f9bd2cf2|1702738160.9032493" .
#
# card:1ed3a44d-c2d5-4f06-87cd-860f8ea4ec93 a owl:Class,
#         l:Card ;
#     l:Attribute info:3ac09a1d-6302-4934-afd6-601cb09028c2 ;
#     d:categopath "concrete_thing|fabricated_thing|created_location|territory|city" ;
#     d:categosens "city",
#         "concrete_thing",
#         "created_location",
#         "fabricated_thing",
#         "territory" ;
#     d:finestCategosens "city" ;
#     d:lemma "mumbai_branch" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:35" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "180:193" ;
#     m:uniqueId "1ed3a44d-c2d5-4f06-87cd-860f8ea4ec93|1702738160.8298185" .
#
# card:25d4023d-0dbc-4ade-82e9-e1624d378d0c a owl:Class,
#         l:Card ;
#     l:Attribute info:43c651a4-4940-483c-8afd-e4f75dc2da6a,
#         info:72b0402c-dfea-4a0c-8a2f-ff4c2a80f608 ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|person_by_name|person_by_firstname" ;
#     d:categosens "[person_by_characteristics]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_firstname",
#         "person_by_name" ;
#     d:finestCategosens "person_by_firstname" ;
#     d:lemma "harry" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:7" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "50:55" ;
#     m:uniqueId "25d4023d-0dbc-4ade-82e9-e1624d378d0c|1702738160.8300145" .
#
# card:2bc33619-06ee-4ba9-bea6-fb701a65541c a owl:Class,
#         l:Card ;
#     l:Attribute info:aac195d1-04fa-4fb1-b880-2949af771684 ;
#     d:categopath "abstract_thing|[features]|communication_element|communication_product|utterance" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "communication_element",
#         "communication_product",
#         "utterance" ;
#     d:finestCategosens "utterance" ;
#     d:lemma "text" ;
#     l:Event info:6e2aac9f-388d-4d21-83b4-0f3936365f4c ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:2" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "16:20" ;
#     m:uniqueId "2bc33619-06ee-4ba9-bea6-fb701a65541c|1702738160.9381187" .
#
# card:2cb769b1-9f36-40ae-b2f3-5b0b0d03793d a owl:Class,
#         l:Card ;
#     l:Attribute info:7e539402-e2c2-4aa6-9137-db9c092d4c23 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|language|code" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "code",
#         "communication_element",
#         "language",
#         "mean_of_expression" ;
#     d:finestCategosens "code" ;
#     d:lemma "'empname'" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:44" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "270:279" ;
#     m:uniqueId "2cb769b1-9f36-40ae-b2f3-5b0b0d03793d|1702738160.9299116" .
#
# card:2e749b05-7612-4e5b-bdc7-a91c8dd41a46 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:4" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "17:20" ;
#     m:uniqueId "2e749b05-7612-4e5b-bdc7-a91c8dd41a46|1702738160.8104787" ;
#     l:Possessing info:28a4cc5e-9caa-44d9-b12d-ce15c121d74c .
#
# card:2ef2368a-dd08-4c5d-baa2-9567ba4c038e a owl:Class,
#         l:Card ;
#     l:Attribute info:00fb9756-3e74-4a6d-b0ed-ad222ccebe26,
#         info:b76e07cd-4e51-49ea-b022-86413c49e739,
#         info:e5424a8b-f7af-481e-b203-7b49c13144c4 ;
#     d:lemma "GHOST_CARD" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "" ;
#     m:uniqueId "2ef2368a-dd08-4c5d-baa2-9567ba4c038e|1702738160.810736" .
#
# card:3043197d-4071-4e91-a983-203344c4878d a owl:Class,
#         l:Card ;
#     l:Attribute info:006bbee7-1c11-4a93-a9ac-1b7016f85449,
#         info:cad6b31b-0c91-40ba-af59-8bf19873eef0 ;
#     d:categopath "abstract_thing|[features]|attribute" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "attribute" ;
#     d:finestCategosens "attribute" ;
#     d:lemma "property" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:3" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "15:23" ;
#     m:uniqueId "3043197d-4071-4e91-a983-203344c4878d|1702738160.835709" .
#
# card:32c1c7c5-6259-451d-a86f-523b137ad25a a owl:Class,
#         l:Card ;
#     l:Attribute info:acc3c3bd-1b51-46f0-a115-b8d28966ab0e ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|[organizations]|organization" ;
#     d:categosens "[organizations]",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "organization",
#         "person" ;
#     d:finestCategosens "organization" ;
#     d:lemma "department" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:28" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "179:190" ;
#     m:uniqueId "32c1c7c5-6259-451d-a86f-523b137ad25a|1702738160.9152994" ;
#     l:Possessing info:9bfcfb6c-1ab6-4dc8-8afe-7674ffed570d .
#
# card:35267923-85be-4c8f-bce7-d242bbee7c09 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:27" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "200:203" ;
#     m:uniqueId "35267923-85be-4c8f-bce7-d242bbee7c09|1702738160.9215646" ;
#     l:Possessing info:0c2a064d-6bfa-414c-bdf0-b4709e753061 .
#
# card:3a3cb474-83c8-41de-b0ad-fdbd60f67e09 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:9" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "52:55" ;
#     m:uniqueId "3a3cb474-83c8-41de-b0ad-fdbd60f67e09|1702738160.937983" ;
#     l:Possessing info:4cc41539-7278-428d-b9c7-cf8edccdd7ec .
#
# card:3e8ed258-52a9-43b6-a71a-df0cb32f0e3f a owl:Class,
#         l:Card ;
#     l:Attribute info:b3f24fb6-abb7-45e2-b6b5-b3ad11fdba16 ;
#     d:lemma "GHOST_CARD" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "" ;
#     m:uniqueId "3e8ed258-52a9-43b6-a71a-df0cb32f0e3f|1702738160.921931" .
#
# card:426a3e02-c4bc-4a39-a51e-f2afb640c7bf a owl:Class,
#         l:Card ;
#     l:Attribute info:3bd19533-9581-4317-b2ce-ad8d9d133417 ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|[organizations]|organization_by_toponym" ;
#     d:categosens "[organizations]",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "organization_by_toponym",
#         "person" ;
#     d:finestCategosens "organization_by_toponym" ;
#     d:lemma "france_branch" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:31" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "148:161" ;
#     m:uniqueId "426a3e02-c4bc-4a39-a51e-f2afb640c7bf|1702738160.8298416" .
#
# card:449fcb7a-b0d7-45d4-80fb-1d72ef237a29 a owl:Class,
#         l:Card ;
#     l:Attribute info:2685fa4b-cb2e-494c-9e6f-81933c0bf28d ;
#     d:lemma "GHOST_CARD" ;
#     l:Event info:3ca6ccad-ee5e-4b22-ab02-cb9ccd325726,
#         info:81710f1e-54c3-4cbf-a4c9-df69454e8721 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "" ;
#     m:uniqueId "449fcb7a-b0d7-45d4-80fb-1d72ef237a29|1702738160.8359406" .
#
# card:489565b7-b659-4c60-84a4-a060758ec04d a owl:Class,
#         l:Card ;
#     l:Attribute info:80c96782-c25b-4976-8672-edf764922679,
#         info:83f4631e-b865-4b7d-aee1-497c6bdbb982,
#         info:8f164e8e-e4d3-4da3-a5c5-5c79004800a3 ;
#     d:lemma "GHOST_CARD" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "" ;
#     m:uniqueId "489565b7-b659-4c60-84a4-a060758ec04d|1702738160.9035797" .
#
# card:4e608f4f-9b02-4903-a58f-939e17e459f8 a owl:Class,
#         l:Card ;
#     d:lemma "GHOST_CARD" ;
#     l:Event info:124cb296-e433-46ca-8d3d-3978f860273e,
#         info:b35f1227-7ed2-4ffc-a2fd-52005c55cea0 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "" ;
#     m:uniqueId "4e608f4f-9b02-4903-a58f-939e17e459f8|1702738160.9303503" .
#
# card:50fc9402-0b25-40b1-b916-914775752209 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:35" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "264:267" ;
#     m:uniqueId "50fc9402-0b25-40b1-b916-914775752209|1702738160.9214988" ;
#     l:Possessing info:bb19052f-b54c-4abb-b582-2ecb7c36589b .
#
# card:52218f75-f6ce-4c03-881d-27df581ea629 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:7aba740f-9de0-4442-84be-e212a240b49f,
#         info:a19dbbea-9770-41fa-ba2f-33723c69a5f7,
#         info:def8deef-6248-4d03-bfab-c85db7aa3d2e ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:0" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "0:2" ;
#     m:uniqueId "52218f75-f6ce-4c03-881d-27df581ea629|1702738160.9153419" .
#
# card:5997e690-5859-4b17-959e-bab339b2832f a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:1ba89fe8-a8c6-4045-82de-f13182e7039e,
#         info:ba730bd6-5eb6-4ac8-9367-8a46b7569d0c,
#         info:d25d038d-693f-45a0-b039-0588e1cc13b8 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:0|1:3" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "0:2|149:151" ;
#     m:uniqueId "5997e690-5859-4b17-959e-bab339b2832f|1702738160.8179612" .
#
# card:6798bfd3-c468-4275-94fd-28be72a70618 a owl:Class,
#         l:Card ;
#     l:Attribute info:c7fb8cb9-1591-4e12-8601-916016e5d4a4 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|language|code" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "code",
#         "communication_element",
#         "language",
#         "mean_of_expression" ;
#     d:finestCategosens "code" ;
#     d:lemma "'joinedon'" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:54" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "326:336" ;
#     m:uniqueId "6798bfd3-c468-4275-94fd-28be72a70618|1702738160.9298851" .
#
# card:6e156acd-185c-4623-94f9-61fa09627b55 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:0" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "0:3" ;
#     m:uniqueId "6e156acd-185c-4623-94f9-61fa09627b55|1702738160.9028049" ;
#     l:Possessing info:3ec9f078-30a0-4e53-ad12-6429ba25ba08 .
#
# card:7242c2cb-f67b-4705-990c-b5c363081899 a owl:Class,
#         l:Card ;
#     l:Attribute info:6846b3da-8a22-4510-bdf7-19ac904566bd ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "junior" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:45" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "240:246" ;
#     m:uniqueId "7242c2cb-f67b-4705-990c-b5c363081899|1702738160.9030855" .
#
# card:7687d3c1-7a19-4ae8-8a89-a933c5764ac4 a owl:Class,
#         l:Card ;
#     l:Attribute info:0453f164-ca5a-4679-80e0-b0502ccb4ce4 ;
#     d:categopath "concrete_thing|natural_thing|other_living_being|eukaryote|animal|chordate|vertebrate|tetrapod|bird" ;
#     d:categosens "animal",
#         "bird",
#         "chordate",
#         "concrete_thing",
#         "eukaryote",
#         "natural_thing",
#         "other_living_being",
#         "tetrapod",
#         "vertebrate" ;
#     d:finestCategosens "bird" ;
#     d:lemma "intern" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation true ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:24" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "137:143" ;
#     m:uniqueId "7687d3c1-7a19-4ae8-8a89-a933c5764ac4|1702738160.9032915" .
#
# card:8317bd2b-cb34-4fb4-b00b-54e86506947c a owl:Class,
#         l:Card ;
#     l:Attribute info:ceba5d2c-53ea-4cd6-b60c-1a5b8b538499 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|language|code" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "code",
#         "communication_element",
#         "language",
#         "mean_of_expression" ;
#     d:finestCategosens "code" ;
#     d:lemma "'empid'" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:34" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "213:220" ;
#     m:uniqueId "8317bd2b-cb34-4fb4-b00b-54e86506947c|1702738160.9299805" .
#
# card:8cefe111-c6e1-40cc-9ca8-7d750a88ae31 a owl:Class,
#         l:Card ;
#     l:Attribute info:7a687ff8-dabf-49fe-a4d4-f4747e6ca039 ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:44" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "321:326" ;
#     m:uniqueId "8cefe111-c6e1-40cc-9ca8-7d750a88ae31|1702738160.9214315" .
#
# card:9491a544-9f63-4e8b-bb6f-38b603d63b86 a owl:Class,
#         l:Card ;
#     l:Attribute info:11574ff5-6d72-4e7d-8a5f-3c2a3ff85297 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "senior" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:81" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "410:416" ;
#     m:uniqueId "9491a544-9f63-4e8b-bb6f-38b603d63b86|1702738160.902887" .
#
# card:98079b75-7e1e-4757-99db-fb93cf782140 a owl:Class,
#         l:Card ;
#     l:Attribute info:cb54ccac-0d2a-4aa0-b2c4-e15dcbe4d955 ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|[person_by_relationship]|person_by_other_relationship" ;
#     d:categosens "[person_by_characteristics]",
#         "[person_by_relationship]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_other_relationship" ;
#     d:finestCategosens "person_by_other_relationship" ;
#     d:lemma "employee" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:86|0:50" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "430:439|260:269" ;
#     m:uniqueId "98079b75-7e1e-4757-99db-fb93cf782140|1702738160.903495" .
#
# card:9db9036b-501f-449d-b400-a082824640c2 a owl:Class,
#         l:Card ;
#     l:Attribute info:25851293-dc20-4f93-b6d0-bbc23ce35306,
#         info:a5d5ac57-4013-4055-a6d2-58ffb700b962 ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|person_by_name|person_by_firstname" ;
#     d:categosens "[person_by_characteristics]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_firstname",
#         "person_by_name" ;
#     d:finestCategosens "person_by_firstname" ;
#     d:lemma "sina" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:17" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "87:91" ;
#     m:uniqueId "9db9036b-501f-449d-b400-a082824640c2|1702738160.8299289" .
#
# card:a3b07187-6681-45a1-a411-c2c4a4a70ffb a owl:Class,
#         l:Card ;
#     l:Attribute info:424d7d74-6d5f-4051-8d96-d048d5ded1b5 ;
#     d:categopath "situation_jj|situated" ;
#     d:categosens "situated",
#         "situation_jj" ;
#     d:finestCategosens "situated" ;
#     d:lemma "external" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:10" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "62:70" ;
#     m:uniqueId "a3b07187-6681-45a1-a411-c2c4a4a70ffb|1702738160.9034092" .
#
# card:a789381c-7f8e-417f-844b-7d8bfb406c69 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:23ffdc9a-9275-4ca6-8cec-393615ff298e ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:7" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "42:44" ;
#     m:uniqueId "a789381c-7f8e-417f-844b-7d8bfb406c69|1702738160.8249147" .
#
# card:aa30c775-25bf-4874-bb78-b4e365839e96 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'is_a_kind_of'" ;
#     l:Event info:b647c655-50a7-474f-bc8b-53f87341a443 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:16" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "107:121" ;
#     m:uniqueId "aa30c775-25bf-4874-bb78-b4e365839e96|1702738160.9216948" .
#
# card:ad7df33a-3fc5-4f83-bee5-2605d9f74a25 a owl:Class,
#         l:Card ;
#     l:Attribute info:0be66605-9573-45a3-adea-d9d7a30b7942 ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|company" ;
#     d:categosens "company",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "person" ;
#     d:finestCategosens "company" ;
#     d:lemma "human_resource" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:17" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "96:110" ;
#     m:uniqueId "ad7df33a-3fc5-4f83-bee5-2605d9f74a25|1702738160.9033651" .
#
# card:b19e26e3-e013-4627-9529-6d548c6a6a69 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'type" ;
#     l:Event info:86c60a4c-3631-460a-87f2-3eb37d7b368d ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:39" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "289:295" ;
#     m:uniqueId "b19e26e3-e013-4627-9529-6d548c6a6a69|1702738160.921473" .
#
# card:b4cdf1e6-43f8-4057-8a84-231d41d187e8 a owl:Class,
#         l:Card ;
#     l:Attribute info:185f1ded-0e2b-49f2-b84a-0103e1a4f395,
#         info:9e823f4e-9185-498d-89be-c460fc0cc063 ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|person_by_name|person_by_firstname" ;
#     d:categosens "[person_by_characteristics]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_firstname",
#         "person_by_name" ;
#     d:finestCategosens "person_by_firstname" ;
#     d:lemma "hina" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:12" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "69:73" ;
#     m:uniqueId "b4cdf1e6-43f8-4057-8a84-231d41d187e8|1702738160.8299725" .
#
# card:baea7727-9de1-4196-a36b-826ca89fce79 a owl:Class,
#         l:Card ;
#     l:Attribute info:b2c664b6-ce12-4343-b845-ed67bdd5cb9a ;
#     d:categopath "abstract_thing|entity|[activities_(n)]|activity_field|economic_sector|other_economic_sector" ;
#     d:categosens "[activities_(n)]",
#         "abstract_thing",
#         "activity_field",
#         "economic_sector",
#         "entity",
#         "other_economic_sector" ;
#     d:finestCategosens "other_economic_sector" ;
#     d:lemma "marketing" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:43|0:57|0:66" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "229:238|290:299|333:342" ;
#     m:uniqueId "baea7727-9de1-4196-a36b-826ca89fce79|1702738160.9035208" .
#
# card:bafd5226-b625-4bb6-ab45-3994ba411e6c a owl:Class,
#         l:Card ;
#     l:Attribute info:c8993d77-8a28-4862-bf7c-17793407e789 ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|[organizations]|organization" ;
#     d:categosens "[organizations]",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "organization",
#         "person" ;
#     d:finestCategosens "organization" ;
#     d:lemma "department" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:18" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "116:126" ;
#     m:uniqueId "bafd5226-b625-4bb6-ab45-3994ba411e6c|1702738160.9153204" ;
#     l:Possessing info:a838403f-de0d-497b-bef5-9a390fac82aa,
#         info:f9256d6d-5a7e-43fa-a685-b72d4ab01f28 .
#
# card:bb4518bf-0a30-4bb0-9475-414234739aef a owl:Class,
#         l:Card ;
#     l:Attribute info:f89a5f80-a0e5-42f3-b108-e52489dcb965 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "local" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:52" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "271:276" ;
#     m:uniqueId "bb4518bf-0a30-4bb0-9475-414234739aef|1702738160.9030418" .
#
# card:bea6250c-6f8a-4860-9811-bcdf32b4e60b a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'sub-department" ;
#     l:Event info:37c9dfef-c745-43f7-be95-862b4d3b6db6 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:30" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "221:237" ;
#     m:uniqueId "bea6250c-6f8a-4860-9811-bcdf32b4e60b|1702738160.9215426" .
#
# card:c4396e86-5b8a-4d9e-a28b-933444688689 a owl:Class,
#         l:Card ;
#     l:Attribute info:f6cbb60c-3980-4cde-a294-933f88cb71cd ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|[organizations]|organization" ;
#     d:categosens "[organizations]",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "organization",
#         "person" ;
#     d:finestCategosens "organization" ;
#     d:lemma "department" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:22|0:71|0:78" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "124:135|356:367|393:404" ;
#     m:uniqueId "c4396e86-5b8a-4d9e-a28b-933444688689|1702738160.9033144" .
#
# card:c9b283b2-5f39-4dff-a106-b8657ee738d4 a owl:Class,
#         l:Card ;
#     l:Attribute info:57043a8c-dba4-429e-a51c-5008dcf8d3bf ;
#     d:categopath "abstract_thing|entity|[activities_(n)]|activity_field" ;
#     d:categosens "[activities_(n)]",
#         "abstract_thing",
#         "activity_field",
#         "entity" ;
#     d:finestCategosens "activity_field" ;
#     d:lemma "sub-department" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:31" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "196:211" ;
#     m:uniqueId "c9b283b2-5f39-4dff-a106-b8657ee738d4|1702738160.9152775" .
#
# card:c9d24d0a-a7c9-414e-9bd3-c26c53e34ece a owl:Class,
#         l:Card ;
#     l:Attribute info:bd1db438-5976-43ed-97ad-ceffd52f4951 ;
#     d:categopath "concrete_thing|fabricated_thing|created_location|territory|city" ;
#     d:categosens "city",
#         "concrete_thing",
#         "created_location",
#         "fabricated_thing",
#         "territory" ;
#     d:finestCategosens "city" ;
#     d:lemma "delhi_branch" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:27" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "125:137" ;
#     m:uniqueId "c9d24d0a-a7c9-414e-9bd3-c26c53e34ece|1702738160.829775" .
#
# card:d01f673f-9347-40fd-a0e2-3dc255d326d2 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|entity|[indefinite_things]|[related_things]|[analogical_things]|specimen" ;
#     d:categosens "[analogical_things]",
#         "[indefinite_things]",
#         "[related_things]",
#         "abstract_thing",
#         "entity",
#         "specimen" ;
#     d:finestCategosens "specimen" ;
#     d:lemma "example" ;
#     l:Link info:094777dc-4057-4e7d-bcbe-0567a9326fd4 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:0" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "0:8" ;
#     m:uniqueId "d01f673f-9347-40fd-a0e2-3dc255d326d2|1702738160.8300567" ;
#     l:Possessing info:872b3338-6f84-4f0c-874a-cc6a8f9fb569 .
#
# card:d7f2de52-f546-48e7-b4d5-e7b4265704e2 a owl:Class,
#         l:Card ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_activity]|professional" ;
#     d:categosens "[person_by_activity]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "professional" ;
#     d:finestCategosens "professional" ;
#     d:lemma "manager" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:20" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "97:104" ;
#     m:uniqueId "d7f2de52-f546-48e7-b4d5-e7b4265704e2|1702738160.8299077" .
#
# card:dac7d92a-f235-4899-9b4e-70263555b694 a owl:Class,
#         l:Card ;
#     l:Attribute info:ebefb55a-1f24-4b93-aa77-8022880c67dd ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:20" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "148:153" ;
#     m:uniqueId "dac7d92a-f235-4899-9b4e-70263555b694|1702738160.921672" .
#
# card:db679087-bd06-448f-8e6c-1e3703976678 a owl:Class,
#         l:Card ;
#     l:Attribute info:6c697763-74bd-48b3-919a-7983e2fe3b25 ;
#     d:categopath "abstract_thing|[features]|attribute" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "attribute" ;
#     d:finestCategosens "attribute" ;
#     d:lemma "property" ;
#     l:Event info:0bb00cfc-ec05-4d86-95d7-492dd3e4638a ;
#     l:Link info:3fda08f0-f5bd-4f2e-a5ab-96618ded9d47 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:1" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "7:17" ;
#     m:uniqueId "db679087-bd06-448f-8e6c-1e3703976678|1702738160.9218078" .
#
# card:dd67ebb2-b616-47e3-a2c7-7425ac60df63 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'is_a_part_of'" ;
#     l:Event info:6bd357ba-74d0-4501-bcb2-00e04666a655 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:23" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "161:175" ;
#     m:uniqueId "dd67ebb2-b616-47e3-a2c7-7425ac60df63|1702738160.921607" .
#
# card:e18fba56-90f1-42f8-8152-8cca82887046 a owl:Class,
#         l:Card ;
#     l:Attribute info:8727423c-d020-4bf3-b1fd-f585d1189d2b ;
#     d:lemma "GHOST_CARD" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "" ;
#     m:uniqueId "e18fba56-90f1-42f8-8152-8cca82887046|1702738160.8250024" .
#
# card:e2ff8558-9d84-46da-a164-3e0909cee648 a owl:Class,
#         l:Card ;
#     l:Attribute info:841320f5-8609-427c-87d5-3feefd5296c5,
#         info:d4754154-d273-4b99-a378-3c127e74cd31 ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|person_by_name|person_by_firstname" ;
#     d:categosens "[person_by_characteristics]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_firstname",
#         "person_by_name" ;
#     d:finestCategosens "person_by_firstname" ;
#     d:lemma "tara" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:22" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "106:110" ;
#     m:uniqueId "e2ff8558-9d84-46da-a164-3e0909cee648|1702738160.829885" .
#
# card:e32567e3-20fe-4cb9-a16c-654f7aca0106 a owl:Class,
#         l:Card ;
#     l:Attribute info:67ae7715-02c8-4c49-9914-8f808ab8811a,
#         info:87fc5f3a-183b-4a7d-b8ce-cefe862ecf2a ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "epid'" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:14" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "89:94" ;
#     m:uniqueId "e32567e3-20fe-4cb9-a16c-654f7aca0106|1702738160.9302216" .
#
# card:e47b1e98-758f-45a4-8a9d-9e70b3cce5df a owl:Class,
#         l:Card ;
#     l:Attribute info:3cebc3a0-1a5e-4785-9963-e82abd6a125c ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_activity]|professional" ;
#     d:categosens "[person_by_activity]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "professional" ;
#     d:finestCategosens "professional" ;
#     d:lemma "manager" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:59" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "301:308" ;
#     m:uniqueId "e47b1e98-758f-45a4-8a9d-9e70b3cce5df|1702738160.9029994" .
#
# card:e58af0c8-c675-4288-b98e-e5fa78209012 a owl:Class,
#         l:Card ;
#     l:Attribute info:4d9421f1-77a0-4626-afd4-9bf717d2f7a6,
#         info:a05b11b7-e03f-401f-8584-d59a09d842e5,
#         info:c3d6a701-0f7c-4e70-9718-bfcf0f543c0f ;
#     d:lemma "GHOST_CARD" ;
#     l:Event info:3eed4edf-3ce2-4aad-b489-72e407b7c926,
#         info:6d910180-b4d6-4475-ad92-c6a9294e9fba,
#         info:770fe8b7-5d71-4cc0-97ab-38031ec6e83f,
#         info:877d4871-a630-483d-a23a-602e32fb8fb2,
#         info:c056609c-7ed3-4353-a73f-1c1a1cdcf1e8,
#         info:cb7c9fd5-71e0-4cbf-8375-1061d4da4963,
#         info:d01ad3eb-299a-47cf-9c2c-f880623007ec,
#         info:f69a2705-ab50-42fa-baa2-a7d464967dac ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "" ;
#     m:uniqueId "e58af0c8-c675-4288-b98e-e5fa78209012|1702738160.8301036" .
#
# card:ed2dc7d3-11a5-4266-ab69-3f115f135e34 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:ac8ab34e-2312-4709-bf06-8ebbe731a838 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:0" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "0:2" ;
#     m:uniqueId "ed2dc7d3-11a5-4266-ab69-3f115f135e34|1702738160.835895" .
#
# <https://data.lettria.com/document/63369e3f175cea0024662887_document_0> a l:Document ;
#     rdfs:label "63369e3f175cea0024662887_document_0" ;
#     rdf:language "en" ;
#     l:Card card:0be1b1b4-dd8a-41d2-a675-a88403741db3,
#         card:2aed83c8-62a0-407d-ab39-074c40b32e89,
#         card:2e749b05-7612-4e5b-bdc7-a91c8dd41a46,
#         card:2ef2368a-dd08-4c5d-baa2-9567ba4c038e,
#         card:3b2f90c1-05ac-4967-9f1e-ba35fac6ebdc,
#         card:3ecc936b-7147-40ac-84b9-031ac5f8fe81,
#         card:4bb6935d-ef29-4541-b1e3-b50b1f15892f,
#         card:6f644862-3ca3-48ae-9761-6b7585aa9d43,
#         card:75104f26-06c6-44db-9a8c-5cb675e541cb,
#         card:79df25cc-5d2f-4141-8453-ebc4d3e5d4cd,
#         card:e04b7e59-13fb-4a25-a837-9fc2e423a3e5,
#         card:e271d20c-9921-4334-9a0c-2bd07dee011a,
#         card:e6698dde-e49e-4768-9cc1-9db46b62218c,
#         card:f388ee11-e37a-4f91-b118-5532146f62d6,
#         card:fc017370-6b26-47f2-8c05-d4d304cc54f4 ;
#     m:projectId "63369e3f175cea0024662887" .
#
# <https://data.lettria.com/document/63369e3f175cea0024662887_document_1> a l:Document ;
#     rdfs:label "63369e3f175cea0024662887_document_1" ;
#     rdf:language "en" ;
#     l:Card card:1271db75-ad78-494d-969b-6a4eb62a07e2,
#         card:30f1e3f2-19c0-4e7a-a556-2f7e475c4707,
#         card:3ec2cebc-98f1-446d-90d3-821deaeceabe,
#         card:42cc629a-9ee1-4196-849f-393eb0fa219f,
#         card:5997e690-5859-4b17-959e-bab339b2832f,
#         card:67d42a3c-dbb3-4ce2-8d7e-b549e1226e6c,
#         card:76f8550a-4357-4d72-b3be-29a19244a90b,
#         card:7a7b252b-aff1-4bd7-b4fc-17323099d6f0,
#         card:7b026e51-1241-46a5-97f2-3f46ad0d265b,
#         card:7e940b18-24b8-42c4-83e1-51f181e5ce80,
#         card:a53740d6-1061-44aa-86cd-4aacf4300736,
#         card:a97ee80f-70e8-4431-a663-655acbe743bb,
#         card:bc304dea-a6fe-4894-815e-d8f5b11faebe,
#         card:c45a02c5-417b-44ca-bd82-fb2cf6512fa9,
#         card:c7fca44a-10f2-4ae2-837d-4c9b3020dbf1,
#         card:ccd04968-a88b-41ff-8b3e-7a40e6f60a37,
#         card:fe87cd4d-6c60-4f35-b3fa-b6df2f0e1c01 ;
#     m:projectId "63369e3f175cea0024662887" .
#
# <https://data.lettria.com/document/63369e3f175cea0024662887_document_2> a l:Document ;
#     rdfs:label "63369e3f175cea0024662887_document_2" ;
#     rdf:language "en" ;
#     l:Card card:1ced9623-7fa2-4504-8de1-e35268e07966,
#         card:32539ba1-47e5-4a9d-b6d3-b4903a89494c,
#         card:5ad4db63-cf64-4d66-bdc9-11c5eb68e598,
#         card:77319e95-5837-462c-a7e7-5d68472c02ea,
#         card:7b1a7783-da18-4d72-93a3-f6fa23f660f6,
#         card:a6f79ab3-87e4-4f1d-a617-b1a08cdc155f,
#         card:a789381c-7f8e-417f-844b-7d8bfb406c69,
#         card:badaa49a-f58a-4fd4-baf5-622ab23e7e01,
#         card:bfa71fde-ed2a-4cea-a28b-7dc0736d6df9,
#         card:d9caba4d-2246-43cc-89e2-37ee99a41cfa,
#         card:db6823e6-7cb7-4849-8b99-6dc7d68693bc,
#         card:e18fba56-90f1-42f8-8152-8cca82887046 ;
#     m:projectId "63369e3f175cea0024662887" .
#
# <https://data.lettria.com/document/63369e3f175cea0024662887_document_3> a l:Document ;
#     rdfs:label "63369e3f175cea0024662887_document_3" ;
#     rdf:language "en" ;
#     l:Card card:12b148af-d07c-489f-8fa1-c47ae11cefba,
#         card:1ed3a44d-c2d5-4f06-87cd-860f8ea4ec93,
# ...
#
# info:d118e1e8-903f-47ee-8dfc-a7c7e2fad71b a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "date" ;
#     d:value "date" ;
#     d:valueType "string" ;
#     l:Link info:e054f5cd-2dd5-4a35-a74f-8832a5ae0364 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:9|0:11" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "66:70|74:85" ;
#     m:temporality "present" ;
#     m:uniqueId "d118e1e8-903f-47ee-8dfc-a7c7e2fad71b|1702738161.0449533" .
#
# info:d4754154-d273-4b99-a378-3c127e74cd31 a owl:ObjectProperty,
#         l:Attribute ;
#     rdfs:label "Identity" ;
#     d:value card:44b65191-ff81-4965-ab1d-cc59cea57688 ;
#     d:valueType "card" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:intensity 1e+00 ;
#     m:negation true ;
#     m:origin "text" ;
#     m:position "0:22|0:23|0:25" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "106:110|111:113|117:123" ;
#     m:temporality "present" ;
#     m:uniqueId "d4754154-d273-4b99-a378-3c127e74cd31|1702738160.9737437" .
#
# info:e5424a8b-f7af-481e-b203-7b49c13144c4 a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "nationality" ;
#     d:value "internationality" ;
#     d:valueType "string" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:25" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "133:146" ;
#     m:temporality "present" ;
#     m:uniqueId "e5424a8b-f7af-481e-b203-7b49c13144c4|1702738160.9475167" .
#
# info:e744befe-c086-46df-9fae-93c9f95e2b75 a owl:ObjectProperty,
#         l:Event ;
#     rdfs:label "root:interact:interpersonal:capturing:capture" ;
#     d:categopath "root|interact|interpersonal|capturing|capture" ;
#     d:categosens "capture",
#         "capturing",
#         "interact",
#         "interpersonal",
#         "root" ;
#     d:finestCategosens "capture" ;
#     d:value card:6910ba4c-9049-45b0-beee-a27c9b9aa6ee ;
#     d:valueType "card" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:extra "{'verb': 'capture', 'verb_perso': False, 'mode': 'infinitive', 'modality': None}" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:5|0:7" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "29:36|41:48" ;
#     m:temporality "infinitive" ;
#     m:uniqueId "e744befe-c086-46df-9fae-93c9f95e2b75|1702738161.053062" .
#
# info:ec078bdb-897b-40fe-acd2-4c68b8cf1fbb a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "name" ;
#     d:value "name" ;
#     d:valueType "string" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:49|0:51" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "303:307|311:320" ;
#     m:temporality "present" ;
#     m:uniqueId "ec078bdb-897b-40fe-acd2-4c68b8cf1fbb|1702738161.0457368" .
#
# info:f69a2705-ab50-42fa-baa2-a7d464967dac a owl:ObjectProperty,
#         l:Event ;
#     rdfs:label "root:act:moving:place:to/from:stay_(somewhere)" ;
#     d:categopath "root|act|moving|place|to/from|stay_(somewhere)" ;
#     d:categosens "act",
#         "moving",
#         "place",
#         "root",
#         "stay_(somewhere)",
#         "to/from" ;
#     d:finestCategosens "stay_(somewhere)" ;
#     d:value info:3bd19533-9581-4317-b2ce-ad8d9d133417 ;
#     d:valueType "attribute" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:extra "{'verb': 'stat', 'verb_perso': False, 'mode': None, 'modality': None}" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:5|0:32" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "37:44|162:164" ;
#     m:temporality "present" ;
#     m:uniqueId "f69a2705-ab50-42fa-baa2-a7d464967dac|1702738160.974073" .
#
# info:f6cbb60c-3980-4cde-a294-933f88cb71cd a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "kind" ;
#     d:value "type" ;
#     d:valueType "string" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:20|0:22" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "116:120|124:135" ;
#     m:temporality "present" ;
#     m:uniqueId "f6cbb60c-3980-4cde-a294-933f88cb71cd|1702738161.000587" .
#
# card:32539ba1-47e5-4a9d-b6d3-b4903a89494c a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|[manners/practices]|position_(n)" ;
#     d:categosens "[features]",
#         "[manners/practices]",
#         "abstract_thing",
#         "position_(n)" ;
#     d:finestCategosens "position_(n)" ;
#     d:lemma "instance" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation true ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:2" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "16:25" ;
#     m:uniqueId "32539ba1-47e5-4a9d-b6d3-b4903a89494c|1702738160.8247101" .
#
# card:439f0449-337a-43c7-9926-7083e9aae3e0 a owl:Class,
#         l:Card ;
#     l:Attribute info:384d2326-0644-419f-91dd-f2d4ba33dc2f ;
#     d:categopath "abstract_thing|[features]|quantity_(n)|numerical_value" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "numerical_value",
#         "quantity_(n)" ;
#     d:finestCategosens "numerical_value" ;
#     d:lemma "number" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:30" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "192:198" ;
#     m:uniqueId "439f0449-337a-43c7-9926-7083e9aae3e0|1702738160.9301794" .
#
# card:6910ba4c-9049-45b0-beee-a27c9b9aa6ee a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|entity|[indefinite_things]|[qualified_things]|[good/bad_things]|[good_things]|best_thing" ;
#     d:categosens "[good/bad_things]",
#         "[good_things]",
#         "[indefinite_things]",
#         "[qualified_things]",
#         "abstract_thing",
#         "best_thing",
#         "entity" ;
#     d:finestCategosens "best_thing" ;
#     d:lemma "essence" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:7" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "41:48" ;
#     m:uniqueId "6910ba4c-9049-45b0-beee-a27c9b9aa6ee|1702738160.9380975" .
#
# card:75104f26-06c6-44db-9a8c-5cb675e541cb a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|entity|[activities_(n)]|activity_field" ;
#     d:categosens "[activities_(n)]",
#         "abstract_thing",
#         "activity_field",
#         "entity" ;
#     d:finestCategosens "activity_field" ;
#     d:lemma "domain" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:2" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "7:13" ;
#     m:uniqueId "75104f26-06c6-44db-9a8c-5cb675e541cb|1702738160.8107138" .
#
# card:9273d714-14ff-4b16-a94d-cb3bb5751352 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|entity|system" ;
#     d:categosens "abstract_thing",
#         "entity",
#         "system" ;
#     d:finestCategosens "system" ;
#     d:lemma "hierarchy" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:4" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "27:36" ;
#     m:uniqueId "9273d714-14ff-4b16-a94d-cb3bb5751352|1702738160.9034522" .
#
# card:a92ba905-8a76-4444-998e-a90ffcefcd5c a owl:Class,
#         l:Card ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|[person_by_relationship]|person_by_other_relationship" ;
#     d:categosens "[person_by_characteristics]",
#         "[person_by_relationship]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_other_relationship" ;
#     d:finestCategosens "person_by_other_relationship" ;
#     d:lemma "employee" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:14|0:42" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "96:105|306:315" ;
#     m:uniqueId "a92ba905-8a76-4444-998e-a90ffcefcd5c|1702738160.9217176" .
#
# card:b32b236c-7c52-4317-892c-1db1d4e2bf08 a owl:Class,
#         l:Card ;
#     l:Attribute info:47296e44-2bd4-4ad6-b0fa-33ef20003e47 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|visual_sign|graphic_sign" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "communication_element",
#         "graphic_sign",
#         "mean_of_expression",
#         "sign",
#         "visual_sign" ;
#     d:finestCategosens "graphic_sign" ;
#     d:lemma "id" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation true ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:40" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "253:255" ;
#     m:uniqueId "b32b236c-7c52-4317-892c-1db1d4e2bf08|1702738160.9301581" .
#
# card:bb549b9b-d9d3-41fc-b6f7-ac451d9264f6 a owl:Class,
#         l:Card ;
#     l:Attribute info:05cf565a-ea97-4c54-8150-867fdae596f0,
#         info:3505dc92-d6d4-44cb-be7c-8b88cc9e76eb,
#         info:5468a2cb-c9b3-472c-af08-b7b836a0b056,
#         info:74deaea0-c9f3-449d-8982-e63573344abe ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|person_by_name|person_by_firstname" ;
#     d:categosens "[person_by_characteristics]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_firstname",
#         "person_by_name" ;
#     d:finestCategosens "person_by_firstname" ;
#     d:lemma "harry" ;
#     l:Link info:4b4a2034-bdef-40eb-af94-de36427d6775 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:9|0:6" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "53:58|35:46" ;
#     m:uniqueId "bb549b9b-d9d3-41fc-b6f7-ac451d9264f6|1702738160.8359175" .
#
# card:d8861a6a-2d23-41ff-aac5-5019fd44c864 a owl:Class,
#         l:Card ;
#     l:Attribute info:7b6d1a30-4cf8-46d0-837f-5aa9e0b62294 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|visual_sign|graphic_sign" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "communication_element",
#         "graphic_sign",
#         "mean_of_expression",
#         "sign",
#         "visual_sign" ;
#     d:finestCategosens "graphic_sign" ;
#     d:lemma "id" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation true ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:20" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "129:131" ;
#     m:uniqueId "d8861a6a-2d23-41ff-aac5-5019fd44c864|1702738160.9301999" .
#
# card:fe87cd4d-6c60-4f35-b3fa-b6df2f0e1c01 a owl:Class,
#         l:Card ;
#     l:Attribute info:1b158a33-a301-4295-b2c7-3fad53645e5a,
#         info:2176f0ed-fa34-48c2-b1b4-5aa4ddd24151,
#         info:29856dca-3da4-468f-be04-26f86dc96093,
#         info:47f7604a-8d75-430a-b587-9d4fd98b4c3e,
#         info:69fdb7a9-4655-4b15-9da1-2a16a1f33e67,
#         info:89c872ce-43e6-4ce5-9b40-2fcaa0fa22cf,
#         info:9cbcdc62-36ec-47bb-b7a5-23ab0511c2b5,
#         info:a33b6330-ec52-4507-a18b-a31491b03b1c,
#         info:e70a3e24-99d1-4f1f-a6a4-fe127f11b437,
#         info:e710774e-b97e-4d9a-a47b-c7ac551b4315,
#         info:edb9f014-c7dc-447c-ac0a-f0ee8956a872,
#         info:f2ae03e5-7d6b-4bb3-9080-c88019ea1406 ;
#     d:categopath "abstract_thing|[features]|attribute" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "attribute" ;
#     d:finestCategosens "attribute" ;
#     d:lemma "property" ;
#     l:Link info:a5cf06b5-24c0-4dfc-9dd4-eb6762d3e43d,
#         info:da5242dc-3219-43f2-b7d6-ba1dd18cad76 ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "1:6|0:5" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "165:175|40:50" ;
#     m:uniqueId "fe87cd4d-6c60-4f35-b3fa-b6df2f0e1c01|1702738160.817936" .
#
# info:7a687ff8-dabf-49fe-a4d4-f4747e6ca039 a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "kind" ;
#     d:value "type" ;
#     d:valueType "string" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:44|0:45" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "321:326|327:332" ;
#     m:temporality "present" ;
#     m:uniqueId "7a687ff8-dabf-49fe-a4d4-f4747e6ca039|1702738161.0340955" .
#
# info:ebefb55a-1f24-4b93-aa77-8022880c67dd a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "kind" ;
#     d:value "type" ;
#     d:valueType "string" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:20|0:21" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "148:153|154:159" ;
#     m:temporality "present" ;
#     m:uniqueId "ebefb55a-1f24-4b93-aa77-8022880c67dd|1702738161.0331697" .
#
# card:9f6a1673-3abc-4a3a-bb4d-71cb713aebd5 a owl:Class,
#         l:Card ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|[organizations]|organization" ;
#     d:categosens "[organizations]",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "organization",
#         "person" ;
#     d:finestCategosens "organization" ;
#     d:lemma "department" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:8|0:12|0:18" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "50:61|79:90|131:142" ;
#     m:uniqueId "9f6a1673-3abc-4a3a-bb4d-71cb713aebd5|1702738160.9218538" .
#
# info:a838403f-de0d-497b-bef5-9a390fac82aa a owl:ObjectProperty,
#         l:Possessing ;
#     rdfs:label "ownership:part" ;
#     d:value card:3474ef9a-b1a0-4d4b-bc23-e37d2d7c94c7 ;
#     d:valueType "card" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:35|0:37|0:14|0:18" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "230:235|238:242|93:97|116:126" ;
#     m:temporality "present" ;
#     m:uniqueId "a838403f-de0d-497b-bef5-9a390fac82aa|1702738161.022319" .
#
# info:f9256d6d-5a7e-43fa-a685-b72d4ab01f28 a owl:ObjectProperty,
#         l:Possessing ;
#     rdfs:label "ownership:part" ;
#     d:value card:35e1e2dc-11ef-42f2-bdb2-861a00874cbd ;
#     d:valueType "card" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:21" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:12|0:13|0:14|0:18" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "77:88|89:92|93:97|116:126" ;
#     m:temporality "present" ;
#     m:uniqueId "f9256d6d-5a7e-43fa-a685-b72d4ab01f28|1702738161.0222673" .
#
# card:fbd408cb-0bb7-4e73-adc6-93ed16ef9c7c a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|entity|[activities_(n)]|activity_field" ;
#     d:categosens "[activities_(n)]",
#         "abstract_thing",
#         "activity_field",
#         "entity" ;
#     d:finestCategosens "activity_field" ;
#     d:lemma "sub-department" ;
#     m:creationDate "Saturday, December 16, 2023 02:49:20" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:28|0:36" ;
#     m:projectId "63369e3f175cea0024662887" ;
#     m:purePosition "204:219|268:283" ;
#     m:uniqueId "fbd408cb-0bb7-4e73-adc6-93ed16ef9c7c|1702738160.9219074" .
