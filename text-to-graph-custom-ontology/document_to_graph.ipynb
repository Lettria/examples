# %% [markdown]
# #### Extract document text chunks

# %%
import requests

api_host = 'https://api.lettria.com'
api_route = api_host + '/parse'
document_file_name = 'file.txt'
document_file_location = './data/'
jwt_token_file = 'jwt_token.txt'
jwt_token = open(jwt_token_file, 'r').read()

chunks = []
with open(document_file_location + document_file_name, 'rb') as file:
    response = requests.post(
        api_route,
        files=[('file', ( document_file_name, file, "application/text"))],
        headers={"Authorization":"LettriaProKey " + jwt_token}
    ).json()
    text_chunks = response['chunks']

text_chunks = [chunk['content'] for chunk in text_chunks if chunk['type'] == 'text']
print(text_chunks)
# Out:
# ['In the domain of our ontology, we define various classes such as Departments, Employees, External, Human_Resource, Intern, Internal, International, Junior, Local, Manager, Marketing, Office, Operations, and Senior.', "We establish relationships using object properties like 'has,' 'have,' 'is_a_kind_of,' 'is_a_part_of,' 'sub-departments,' and 'types.' Additionally, we utilize data properties such as 'createdON,' 'depID,' 'empContact,' 'empID,' 'empName,' and 'joinedON.'", 'Individuals are instances of classes, and we have named individuals like Harry, Hina, Sina, Tara, delhi_branch, france_branch, mumbai_branch, and opcore.', 'Examples of class assertions include stating that Harry is a Senior, Hina is a Junior, Sina is a Manager, Tara is an Intern, delhi_branch is Local, france_branch is International, mumbai_branch is Human_Resource, and opcore is Operations.', "We assert data property values for individuals, like Harry's employee contact, ID, name, and joining date. Similar assertions are made for other individuals.", 'Our ontology specifies the hierarchy of classes, stating that External is a type of Operations, Human_Resource is a type of Departments, Intern is a type of Employees, Internal is a type of Operations, International is a type of Marketing, Junior is a type of Employees, Local is a type of Marketing, Manager is a type of Employees, Marketing is a type of Departments, Operations is a type of Departments, and Senior is a type of Employees.', 'We also express relationships between classes, such as stating that External departments are part of the Operations department, Human Resource departments are part of the overall Departments, and Sub-departments are equivalent to being a part of departments.', "Object properties like 'has' connect Offices with Departments, 'have' connects Departments with Employees, 'is_a_kind_of' connects Departments with their types, 'is_a_part_of' connects Marketing with its sub-departments, 'sub-departments' connects Operations with its sub-departments, and 'types' connects Employees with their types.", "Data properties like 'createdON' are associated with the creation date of Departments, 'depID' is associated with the department ID of Departments, 'empContact' is associated with the contact number of Employees, 'empID' is associated with the employee ID of Employees, 'empName' is associated with the name of Employees, and 'joinedON' is associated with the joining date of Employees.", 'This abstracted text aims to capture the essence of our RDF ontology, providing a foundation for structuring and understanding the relationships within the data.']

# %% [markdown]
# #### Text to graph using Lettria structuration endpoint

# %%
api_route = api_host + '/structuration'

response = requests.post(
    api_route,
    json={
        "documents": text_chunks,
        "options":{
            "rdf_export": True
        }
    },
    headers={"Authorization":"LettriaProKey " + jwt_token}
).json()

rdf_string = response['rdf']
print(rdf_string)
# Out:
# @prefix card: <https://data.lettria.com/card/> .
# @prefix d: <https://doc.lettria.com/ontology/1.0/Data/> .
# @prefix info: <https://data.lettria.com/info/> .
# @prefix l: <https://doc.lettria.com/ontology/1.0/> .
# @prefix m: <https://doc.lettria.com/ontology/1.0/Metadata/> .
# @prefix owl: <http://www.w3.org/2002/07/owl#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <https://data.lettria.com/project/6573456c537dc2002c9ae1eb> a l:Project ;
#     rdfs:label "6573456c537dc2002c9ae1eb" ;
#     l:Document <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_0>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_1>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_2>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_3>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_4>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_5>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_6>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_7>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_8>,
#         <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_9> ;
#     m:platformUrl "https://app.lettria.com/nlp/project/view/6573456c537dc2002c9ae1eb/overview" ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# card:005982a6-6762-47ff-8cbd-b044e3c240ba a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:0" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "0:3" ;
#     m:uniqueId "005982a6-6762-47ff-8cbd-b044e3c240ba|1702053461.544506" ;
#     l:Possessing info:e8fa9cab-02da-41a6-afb4-db3bfd23bb59 .
#
# card:04b38081-3f3a-48a8-b363-7600da4f45c9 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:b9a6194b-dabf-42d2-97e7-6c95aa040255,
#         info:dd6772a5-dfbf-4e13-a0b1-b3220f4c08bf,
#         info:f69904a6-64cc-49cb-a3ff-54ec60c20c83 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:0|1:3" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "0:2|149:151" ;
#     m:uniqueId "04b38081-3f3a-48a8-b363-7600da4f45c9|1702053461.5244951" .
#
# card:06db7341-1806-433e-b860-3e719da8767c a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:35" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "264:267" ;
#     m:uniqueId "06db7341-1806-433e-b860-3e719da8767c|1702053461.5580919" ;
#     l:Possessing info:2ce75b55-71b7-4860-950a-9035c697707f .
#
# card:06e8f4f0-61b1-4fd5-891c-f2051b99e77e a owl:Class,
#         l:Card ;
#     l:Attribute info:3fa7a9bf-8434-4560-aba8-d5492de619f3 ;
#     d:lemma "GHOST_CARD" ;
#     l:Event info:91d1257b-fda7-4664-9971-3cd7d13b8efe,
#         info:ca868e1d-b4eb-4f64-8c76-4240283ded44 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:uniqueId "06e8f4f0-61b1-4fd5-891c-f2051b99e77e|1702053461.5380032" .
#
# card:09a029eb-b22f-4a3f-9316-4f5ae8203ee8 a owl:Class,
#         l:Card ;
#     l:Attribute info:0a7b30b3-6f8b-4bb6-ac68-0412814dadb1 ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:20" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "148:153" ;
#     m:uniqueId "09a029eb-b22f-4a3f-9316-4f5ae8203ee8|1702053461.5582821" .
#
# card:11bcf618-7ef2-4d7d-af16-0a03cdea38e5 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:4|0:31|0:40" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "26:29|236:239|294:297" ;
#     m:uniqueId "11bcf618-7ef2-4d7d-af16-0a03cdea38e5|1702053461.5584188" .
#
# card:13c98c4e-3b64-4014-a370-d8f0dacaebb2 a owl:Class,
#         l:Card ;
#     l:Attribute info:97d4f74f-03ff-4a84-95ed-527b63c2c7e1 ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|[organizations]|organization" ;
#     d:categosens "[organizations]",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "organization",
#         "person" ;
#     d:finestCategosens "organization" ;
#     d:lemma "department" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:18" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "116:126" ;
#     m:uniqueId "13c98c4e-3b64-4014-a370-d8f0dacaebb2|1702053461.5532587" ;
#     l:Possessing info:7acff843-55af-40ce-a5f3-e30a0ac713f3,
#         info:d5fbd4d6-0741-4144-8cad-7ea2cb30240c,
#         info:fa917f8f-d731-49ad-85ee-7a9f517dea64 .
#
# card:18b2b046-eee2-4742-9dbc-50e9be2511c8 a owl:Class,
#         l:Card ;
#     l:Attribute info:40f88216-1291-4c77-a2b9-ddefd513a4bc,
#         info:f56e74bf-d03f-4f5e-b99d-37ad464937bb ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "epid'" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:14" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "89:94" ;
#     m:uniqueId "18b2b046-eee2-4742-9dbc-50e9be2511c8|1702053461.5660882" .
#
# card:19322806-4295-48b5-8b37-ddc9b34c59f3 a owl:Class,
#         l:Card ;
#     l:Attribute info:192e9de1-9113-42ee-b958-e3a745fc2f49 ;
#     d:categopath "concrete_thing|fabricated_thing|created_location|territory|city" ;
#     d:categosens "city",
#         "concrete_thing",
#         "created_location",
#         "fabricated_thing",
#         "territory" ;
#     d:finestCategosens "city" ;
#     d:lemma "delhi_branch" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:27" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "125:137" ;
#     m:uniqueId "19322806-4295-48b5-8b37-ddc9b34c59f3|1702053461.5333493" .
#
# card:195e8ab9-05ee-45c4-bdd0-40fd14a26cc9 a owl:Class,
#         l:Card ;
#     l:Attribute info:72099624-f2ca-4d4e-a276-58a05df0a087 ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:44" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "321:326" ;
#     m:uniqueId "195e8ab9-05ee-45c4-bdd0-40fd14a26cc9|1702053461.5580022" .
#
# card:255deb32-6fcb-45c3-9289-542e61c62272 a owl:Class,
#         l:Card ;
#     l:Attribute info:923ece2d-c577-46e7-8945-c16b9173dd64 ;
#     d:categopath "concrete_thing|natural_thing|person|[person_by_characteristics]|[person_by_relationship]|person_by_other_relationship" ;
#     d:categosens "[person_by_characteristics]",
#         "[person_by_relationship]",
#         "concrete_thing",
#         "natural_thing",
#         "person",
#         "person_by_other_relationship" ;
#     d:finestCategosens "person_by_other_relationship" ;
#     d:lemma "employee" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:11" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "61:69" ;
#     m:uniqueId "255deb32-6fcb-45c3-9289-542e61c62272|1702053461.5377567" .
#
# card:2864722a-f2ef-4694-a6a5-cb11ad19499c a owl:Class,
#         l:Card ;
#     l:Attribute info:2fd378c2-3163-435c-87fe-94a3db8d5c43 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|language|code" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "code",
#         "communication_element",
#         "language",
#         "mean_of_expression" ;
#     d:finestCategosens "code" ;
#     d:lemma "'empid'" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:34" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "213:220" ;
#     m:uniqueId "2864722a-f2ef-4694-a6a5-cb11ad19499c|1702053461.5657494" .
#
# card:2ecb1de9-b1e7-42ad-8a28-0da577de2ce8 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:27" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "200:203" ;
#     m:uniqueId "2ecb1de9-b1e7-42ad-8a28-0da577de2ce8|1702053461.5582147" ;
#     l:Possessing info:a7c3e223-8b7f-4b56-a996-d461a5257608 .
#
# card:33f4c8db-ff86-48ce-8fca-363b44a180d2 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'is_a_part_of'" ;
#     l:Event info:d2a84693-ee08-474a-b790-cdf54d1f3c12 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:23" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "161:175" ;
#     m:uniqueId "33f4c8db-ff86-48ce-8fca-363b44a180d2|1702053461.5582604" .
#
# card:3f6658b1-52a2-4e38-b7f1-e3e7aaa705a6 a owl:Class,
#         l:Card ;
#     l:Attribute info:a6fdab1a-dee0-4491-971e-e4665908cf8f ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|language|code" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "code",
#         "communication_element",
#         "language",
#         "mean_of_expression" ;
#     d:finestCategosens "code" ;
#     d:lemma "'empname'" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:44" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "270:279" ;
#     m:uniqueId "3f6658b1-52a2-4e38-b7f1-e3e7aaa705a6|1702053461.56569" .
#
# card:516c1878-1c6f-4588-90f0-f8fb36fd2628 a owl:Class,
#         l:Card ;
#     l:Attribute info:613e93a2-99e6-4663-a604-ab3631d63516 ;
#     d:lemma "GHOST_CARD" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:uniqueId "516c1878-1c6f-4588-90f0-f8fb36fd2628|1702053461.5186846" .
#
# card:53cbded0-1192-43ed-a8fd-da3b297a916f a owl:Class,
#         l:Card ;
#     l:Attribute info:1e896f5d-5f71-4928-b43b-04c1d5b1a25c ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|language|code" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "code",
#         "communication_element",
#         "language",
#         "mean_of_expression" ;
#     d:finestCategosens "code" ;
#     d:lemma "'joinedon'" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:54" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "326:336" ;
#     m:uniqueId "53cbded0-1192-43ed-a8fd-da3b297a916f|1702053461.5656571" .
#
# card:5fc1d946-3283-41f0-84e7-e6ab5da4525e a owl:Class,
#         l:Card ;
#     l:Attribute info:b4399976-52c6-417f-acbb-7c73f05e4d1f ;
#     d:categopath "abstract_thing|[features]|communication_element|communication_product|utterance" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "communication_element",
#         "communication_product",
#         "utterance" ;
#     d:finestCategosens "utterance" ;
#     d:lemma "text" ;
#     l:Event info:9a73e1e2-1116-4e06-82e1-86e7b2b57c91 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:2" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "16:20" ;
#     m:uniqueId "5fc1d946-3283-41f0-84e7-e6ab5da4525e|1702053461.5720901" .
#
# card:64d914b2-e8e9-42f3-a069-aa3eff956afe a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'have'" ;
#     l:Event info:91a6afe7-191d-4881-b8d7-b2cb21545ab5 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:10" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "63:69" ;
#     m:uniqueId "64d914b2-e8e9-42f3-a069-aa3eff956afe|1702053461.5583687" .
#
# card:6573461f49582e002a8bbd91 a owl:Class,
#         l:Card ;
#     l:Attribute info:a6e114e0-faf2-43b1-8bec-c7e032950104 ;
#     d:categopath "root|departments|marketing|local" ;
#     d:categosens "departments",
#         "local",
#         "marketing",
#         "root" ;
#     d:finestCategosens "local" ;
#     d:lemma "local" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false ;
#     m:position "0:52" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "271:276" ;
#     m:uniqueId "6573461f49582e002a8bbd91|1702053461.5447352" .
#
# card:6762e884-2762-43ca-8fe0-38e215a2f3f4 a owl:Class,
#         l:Card ;
#     l:Attribute info:ead5004a-0950-4994-a91d-a997c8538b54 ;
#     d:categopath "situation_jj|situated" ;
#     d:categosens "situated",
#         "situation_jj" ;
#     d:finestCategosens "situated" ;
#     d:lemma "external" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:10" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "62:70" ;
#     m:uniqueId "6762e884-2762-43ca-8fe0-38e215a2f3f4|1702053461.545071" .
#
# card:70e5de9d-c4d2-4d32-839f-858467aee9ff a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:21460579-b69b-4caf-a126-cc634f61e214 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:7" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "31:33" ;
#     m:uniqueId "70e5de9d-c4d2-4d32-839f-858467aee9ff|1702053461.5185928" .
#
# card:76901656-9f25-4bbd-90ef-20a68455c6c4 a owl:Class,
#         l:Card ;
#     l:Attribute info:0b1546e8-99f6-47e6-a966-20cb55be3c9b ;
#     d:lemma "GHOST_CARD" ;
#     l:Event info:1e98ffb9-83a5-4067-aa97-634f3ab02f6a,
#         info:395b07da-844f-4d1b-b787-617afc92493c,
#         info:68c48d5e-3e80-4828-9951-387bbc5e02c4,
#         info:6964275e-bf31-490d-8737-8f8fa4f6274d,
#         info:6cd547c5-3dc3-4b0d-8163-0da1f1d6afb3,
#         info:c8ce8b1f-8052-4358-8000-e28bec4becbf,
#         info:f36fb25d-583f-48b9-8eec-9de09c9036ac,
#         info:ffb691da-9949-490c-a686-3324b38ac25d ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:uniqueId "76901656-9f25-4bbd-90ef-20a68455c6c4|1702053461.5336568" .
#
# card:7cfd3b6c-dc41-4ce7-b6c8-d83dd0768dfc a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:328ae06a-0f9e-42cf-b7b1-b5b3e9c5009b ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:7" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "42:44" ;
#     m:uniqueId "7cfd3b6c-dc41-4ce7-b6c8-d83dd0768dfc|1702053461.529424" .
#
# card:7e1bca3a-23c1-4539-9324-32686e937b86 a owl:Class,
#         l:Card ;
#     l:Attribute info:bf075667-35b2-4cdb-8905-0f04f1f22697 ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|language|code" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "code",
#         "communication_element",
#         "language",
#         "mean_of_expression" ;
#     d:finestCategosens "code" ;
#     d:lemma "'empcontact'" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:24" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "148:160" ;
#     m:uniqueId "7e1bca3a-23c1-4539-9324-32686e937b86|1702053461.5658028" .
#
# card:84cf56e5-dcfc-4d2a-af55-31e9ba7b61a7 a owl:Class,
#         l:Card ;
#     l:Attribute info:9e601d96-5df6-4d52-986c-e7ff7e97d9f4 ;
#     d:lemma "GHOST_CARD" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:uniqueId "84cf56e5-dcfc-4d2a-af55-31e9ba7b61a7|1702053461.545253" .
#
# card:88e23af1-9025-4a4f-b571-ec679cd14d0f a owl:Class,
#         l:Card ;
#     d:lemma "GHOST_CARD" ;
#     l:Event info:088e10c3-8209-4e59-9ac3-b85578cad983,
#         info:ceb3af52-0e1d-4782-9438-ef03664ea818 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:uniqueId "88e23af1-9025-4a4f-b571-ec679cd14d0f|1702053461.5662265" .
#
# card:89c2bfe4-b882-4fb4-9222-de836d84d188 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:9" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "52:55" ;
#     m:uniqueId "89c2bfe4-b882-4fb4-9222-de836d84d188|1702053461.5718613" ;
#     l:Possessing info:a8446cf6-8509-4c9d-9f97-21439932e03a .
#
# card:8ae48c03-2e1e-4f6a-83d8-b7dd6970e8f1 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'sub-department" ;
#     l:Event info:dcd0c6fd-45ba-4f5b-aa96-c0d3bff10d42 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:30" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "221:237" ;
#     m:uniqueId "8ae48c03-2e1e-4f6a-83d8-b7dd6970e8f1|1702053461.5581775" .
#
# card:932802dd-fc5d-4524-b586-93a20d7127de a owl:Class,
#         l:Card ;
#     l:Attribute info:a41ac061-f875-4a42-b39e-935b079685aa ;
#     d:categopath "characteristic_jj|other_characteristic" ;
#     d:categosens "characteristic_jj",
#         "other_characteristic" ;
#     d:finestCategosens "other_characteristic" ;
#     d:lemma "internal" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:31" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "168:176" ;
#     m:uniqueId "932802dd-fc5d-4524-b586-93a20d7127de|1702053461.5448656" .
#
# card:9e44acae-9d90-4814-8b2b-2cea9d4a1d57 a owl:Class,
#         l:Card ;
#     l:Attribute info:c2c0fa3b-2537-4203-a4bd-17af1c2ba114 ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|[organizations]|organization_by_toponym" ;
#     d:categosens "[organizations]",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "organization_by_toponym",
#         "person" ;
#     d:finestCategosens "organization_by_toponym" ;
#     d:lemma "france_branch" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:31" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "148:161" ;
#     m:uniqueId "9e44acae-9d90-4814-8b2b-2cea9d4a1d57|1702053461.5334258" .
#
# card:9fe366dc-1b36-47e4-b4ff-ce6fd57eab13 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|entity|[indefinite_things]|[related_things]|[analogical_things]|specimen" ;
#     d:categosens "[analogical_things]",
#         "[indefinite_things]",
#         "[related_things]",
#         "abstract_thing",
#         "entity",
#         "specimen" ;
#     d:finestCategosens "specimen" ;
#     d:lemma "example" ;
#     l:Link info:97dfc237-9950-4d3f-9323-5699e3d7ab9f ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:0" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "0:8" ;
#     m:uniqueId "9fe366dc-1b36-47e4-b4ff-ce6fd57eab13|1702053461.5336077" ;
#     l:Possessing info:8ff8dee5-4474-4ce0-9878-bc060bdfef14 .
#
# card:a5a36bb5-e1e0-43f1-a999-c85a6210835b a owl:Class,
#         l:Card ;
#     d:lemma "GHOST_CARD" ;
#     l:Event info:126bc30f-ae89-4136-ba9a-1c82dcbf9ca3,
#         info:5c2ec19f-9f8c-46a4-b451-37b628ec002f,
#         info:a0fd498c-9508-43d0-978d-6d4161b19216,
#         info:b63fbfed-3d53-487f-a8e9-226d15ea07b0,
#         info:d024c91e-7b0f-4a43-8a68-c69c8ece0785 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:uniqueId "a5a36bb5-e1e0-43f1-a999-c85a6210835b|1702053461.5721152" .
#
# card:b136e6c3-0677-48b7-812b-c3c679c1c1cc a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'is_a_kind_of'" ;
#     l:Event info:d469a477-d1f5-4876-b256-96fe02ae0d06 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:16" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "107:121" ;
#     m:uniqueId "b136e6c3-0677-48b7-812b-c3c679c1c1cc|1702053461.5583105" .
#
# card:c66bbce5-644c-4d56-9813-45a445965b9b a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:3b0b00a3-6b27-4b44-904e-787f9c27f93c,
#         info:89222449-ef6d-4e56-9808-be6be2199145,
#         info:d00359c5-9bd7-40fc-89c6-dea74d51fff0 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:0" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "0:2" ;
#     m:uniqueId "c66bbce5-644c-4d56-9813-45a445965b9b|1702053461.5533023" .
#
# card:ccee082d-6a46-4de2-8711-ce8028ff1885 a owl:Class,
#         l:Card ;
#     l:Attribute info:3ae123d6-f347-498c-b1a4-019aa4f0bfa0,
#         info:c2d5df54-daec-4037-b0ff-ab3a3f863a5d ;
#     d:categopath "abstract_thing|[features]|attribute" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "attribute" ;
#     d:finestCategosens "attribute" ;
#     d:lemma "property" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:3" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "15:23" ;
#     m:uniqueId "ccee082d-6a46-4de2-8711-ce8028ff1885|1702053461.5378218" .
#
# card:d3b8b5fb-8cc0-4f7f-b44c-79cb1cab0b0c a owl:Class,
#         l:Card ;
#     l:Attribute info:10952391-d851-4b61-896a-b13ae6ca55f9,
#         info:415c964a-0a53-4306-8dfc-653c18e9da73 ;
#     d:categopath "abstract_thing|[features]|attribute" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "attribute" ;
#     d:finestCategosens "attribute" ;
#     d:lemma "property" ;
#     l:Link info:d74925d0-2c38-45a1-a4bf-3e2b2dbd4942 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:1" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "5:15" ;
#     m:uniqueId "d3b8b5fb-8cc0-4f7f-b44c-79cb1cab0b0c|1702053461.5661402" .
#
# card:d7b16e3c-0553-4014-bbef-681699f24020 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     l:Event info:bb58c13e-71be-4d43-b9c0-c3932185ef40 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:0" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "0:2" ;
#     m:uniqueId "d7b16e3c-0553-4014-bbef-681699f24020|1702053461.5379605" .
#
# card:d9e549c4-2088-4f9f-813a-c37f89eeaec4 a owl:Class,
#         l:Card ;
#     l:Attribute info:8cfc2db4-27ff-4112-81f9-c7f4558be098 ;
#     d:categopath "abstract_thing|entity|[activities_(n)]|activity_field" ;
#     d:categosens "[activities_(n)]",
#         "abstract_thing",
#         "activity_field",
#         "entity" ;
#     d:finestCategosens "activity_field" ;
#     d:lemma "sub-department" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:30" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "196:211" ;
#     m:uniqueId "d9e549c4-2088-4f9f-813a-c37f89eeaec4|1702053461.553218" .
#
# card:df536221-2b93-4424-ac61-93f453fafc1d a owl:Class,
#         l:Card ;
#     l:Attribute info:ba1452a8-12d4-4bb3-95b5-8dc54c1fc562 ;
#     d:categopath "concrete_thing|fabricated_thing|created_location|territory|city" ;
#     d:categosens "city",
#         "concrete_thing",
#         "created_location",
#         "fabricated_thing",
#         "territory" ;
#     d:finestCategosens "city" ;
#     d:lemma "mumbai_branch" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:35" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "180:193" ;
#     m:uniqueId "df536221-2b93-4424-ac61-93f453fafc1d|1702053461.5334034" .
#
# card:e1528405-3096-435d-9205-f53f7d901451 a owl:Class,
#         l:Card ;
#     l:Attribute info:b6161f70-aae8-408f-b5fe-760c77f681ca ;
#     d:lemma "GHOST_CARD" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation "None" ;
#     m:origin "Lettria" ;
#     m:plural "None" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:uniqueId "e1528405-3096-435d-9205-f53f7d901451|1702053461.5295203" .
#
# card:e7fe67c9-11b9-4594-bbc3-0b3f1fd7d5dd a owl:Class,
#         l:Card ;
#     l:Attribute info:a6f34be9-27f6-4c72-8cd7-ed7a3c2052a3 ;
#     d:categopath "abstract_thing|[features]|attribute" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "attribute" ;
#     d:finestCategosens "attribute" ;
#     d:lemma "property" ;
#     l:Event info:b179274f-54f1-4e20-9f8f-4564e0a07800 ;
#     l:Link info:a90ef381-e665-4b3d-955d-068a29456c18 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:1" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "7:17" ;
#     m:uniqueId "e7fe67c9-11b9-4594-bbc3-0b3f1fd7d5dd|1702053461.5584772" .
#
# card:ecffbe75-37ce-4ea2-b9d4-4c5371701d18 a owl:Class,
#         l:Card ;
#     d:categopath "coreference" ;
#     d:categosens "coreference" ;
#     d:finestCategosens "coreference" ;
#     d:lemma "it" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:4" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "17:20" ;
#     m:uniqueId "ecffbe75-37ce-4ea2-b9d4-4c5371701d18|1702053461.5184526" ;
#     l:Possessing info:85491c56-8320-4ea5-b0f6-0257fa809c1a .
#
# card:ee215135-59ce-4156-86b8-3f195197ecae a owl:Class,
#         l:Card ;
#     l:Attribute info:9d41f102-d52a-4118-8758-6b0f539326fc ;
#     d:categopath "concrete_thing|natural_thing|person|human_group|company" ;
#     d:categosens "company",
#         "concrete_thing",
#         "human_group",
#         "natural_thing",
#         "person" ;
#     d:finestCategosens "company" ;
#     d:lemma "human_resource" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:17" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "96:110" ;
#     m:uniqueId "ee215135-59ce-4156-86b8-3f195197ecae|1702053461.5450115" .
#
# card:fba8e0be-f078-4402-9f89-1fcfcd3a0cb6 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|communication_element|mean_of_expression|sign|language_element|autonym" ;
#     d:categosens "[features]",
#         "abstract_thing",
#         "autonym",
#         "communication_element",
#         "language_element",
#         "mean_of_expression",
#         "sign" ;
#     d:finestCategosens "autonym" ;
#     d:lemma "'type" ;
#     l:Event info:a4b98ca7-0abd-48c1-be6c-aef57e0443a1 ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:39" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "289:295" ;
#     m:uniqueId "fba8e0be-f078-4402-9f89-1fcfcd3a0cb6|1702053461.5580537" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_0> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_0" ;
#     rdf:language "en" ;
#     l:Card card:0f3b2ce0-8997-430e-bc14-c9a640dd2abb,
#         card:14e97c7d-44a2-4d3c-a8d1-f37d108c89ba,
#         card:465878a6-167a-4ded-97b6-1e42d879ce53,
#         card:516c1878-1c6f-4588-90f0-f8fb36fd2628,
#         card:6573461d537dc2002c9ae272,
#         card:6573461d7caa6f00243dde93,
#         card:6573461df297f4002acd80df,
#         card:6573461e49582e002a8bbd4e,
#         card:6573461e49582e002a8bbd67,
#         card:6573461e7caa6f00243ddeac,
#         card:6573461e911ed5002428cd4a,
#         card:6573461ecaa7df0031294288,
#         card:6573461ef297f4002acd80fc,
#         card:6573461f7caa6f00243ddee7,
#         card:70e5de9d-c4d2-4d32-839f-858467aee9ff,
#         card:c079ecb2-23db-4677-982f-57e785dadf6d,
#         card:ecffbe75-37ce-4ea2-b9d4-4c5371701d18 ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_1> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_1" ;
#     rdf:language "en" ;
#     l:Card card:0055123a-88c1-4177-b484-8dac7c08d9cb,
#         card:04b38081-3f3a-48a8-b363-7600da4f45c9,
#         card:05f69c1a-b2c6-4aac-b72f-a26d6fabdb21,
#         card:15ed849c-6d5e-43e7-bcc5-866199df88fb,
#         card:31e92222-0fe1-4cc7-879a-a2ce7ff31186,
#         card:5840a17c-0ebf-47e8-8e8f-0cbf5e3d20ca,
#         card:624209dd-8136-450c-966f-72bcc036e8fe,
#         card:74cb38f7-bc2d-4458-a529-b75b9505aecb,
#         card:8412b0b8-8663-47af-aa91-3cbb1326545d,
#         card:86f4f3d6-4fc7-42f3-a560-377acee3b510,
#         card:9d10015c-beec-4d8f-b184-bdf383a5e1ea,
#         card:a3c6a144-a568-4388-8005-4ca81d3948e6,
#         card:c8899b74-d593-4801-81ff-7be3cd37965e,
#         card:d253f27e-bf92-4ec4-8634-8dc99db0ccc4,
#         card:df89dc98-7759-4f6e-afc7-b1cb2a685eca,
#         card:ebb84a64-3c8a-44f3-95f5-aace46dec9bf,
#         card:fead9496-ffe9-4799-9b7f-5b500c536ab4 ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_2> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_2" ;
#     rdf:language "en" ;
#     l:Card card:0f586244-b108-4653-9c87-900d7ec82c04,
#         card:367a1100-b0ce-46d8-b204-5310410cd261,
#         card:6573461e49582e002a8bbd80,
#         card:6573461e7caa6f00243ddec5,
#         card:6573461e7caa6f00243dded6,
#         card:6573461e911ed5002428cd6b,
#         card:6573461ecaa7df00312942b6,
#         card:7cfd3b6c-dc41-4ce7-b6c8-d83dd0768dfc,
#         card:9ee177cc-75a8-4948-8fc6-b8234e464581,
#         card:a7ccbae4-e9eb-4825-aa42-2838f215309d,
#         card:e1528405-3096-435d-9205-f53f7d901451,
#         card:f1356929-8dab-4f71-84a0-62d724849a1d ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_3> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_3" ;
#     rdf:language "en" ;
#     l:Card card:19322806-4295-48b5-8b37-ddc9b34c59f3,
#         card:6573461e49582e002a8bbd67,
#         card:6573461e49582e002a8bbd80,
#         card:6573461e7caa6f00243ddeac,
#         card:6573461e7caa6f00243ddec5,
#         card:6573461e7caa6f00243dded6,
#         card:6573461e911ed5002428cd4a,
#         card:6573461e911ed5002428cd6b,
#         card:6573461ecaa7df00312942b6,
#         card:6573461ef297f4002acd80fc,
#         card:6573461f7caa6f00243ddee7,
#         card:76901656-9f25-4bbd-90ef-20a68455c6c4,
#         card:9e44acae-9d90-4814-8b2b-2cea9d4a1d57,
#         card:9fe366dc-1b36-47e4-b4ff-ce6fd57eab13,
#         card:b2c47190-6436-47b7-be40-00cbf175a624,
#         card:cfaceac7-3514-466a-bd98-e27076961a59,
#         card:df536221-2b93-4424-ac61-93f453fafc1d ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_4> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_4" ;
#     rdf:language "en" ;
#     l:Card card:06e8f4f0-61b1-4fd5-891c-f2051b99e77e,
#         card:255deb32-6fcb-45c3-9289-542e61c62272,
#         card:6573461ecaa7df00312942b6,
#         card:c9695c8b-855f-489d-b902-49e157ef7e9a,
#         card:ccee082d-6a46-4de2-8711-ce8028ff1885,
#         card:d7b16e3c-0553-4014-bbef-681699f24020,
#         card:dc505433-8757-436b-b70d-40414dc452c0,
#         card:e9305fc1-9d51-414f-8b41-fde91cb4ba40 ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_5> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_5" ;
#     rdf:language "en" ;
#     l:Card card:005982a6-6762-47ff-8cbd-b044e3c240ba,
#         card:1df8e990-6ead-4f97-bea9-63477f6d07a4,
#         card:6573461d537dc2002c9ae272,
#         card:6573461df297f4002acd80df,
#         card:6573461e49582e002a8bbd4e,
#         card:6573461e49582e002a8bbd67,
#         card:6573461e7caa6f00243ddeac,
#         card:6573461e911ed5002428cd4a,
#         card:6573461ecaa7df0031294288,
#         card:6573461ef297f4002acd80fc,
#         card:6573461f49582e002a8bbd91,
#         card:6573461f7caa6f00243ddee7,
#         card:6762e884-2762-43ca-8fe0-38e215a2f3f4,
#         card:84cf56e5-dcfc-4d2a-af55-31e9ba7b61a7,
#         card:8d822955-54c0-4389-98cd-fc15ce999b59,
#         card:932802dd-fc5d-4524-b586-93a20d7127de,
#         card:ee215135-59ce-4156-86b8-3f195197ecae ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_6> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_6" ;
#     rdf:language "en" ;
#     l:Card card:13c98c4e-3b64-4014-a370-d8f0dacaebb2,
#         card:470b7837-f4b4-4c88-8f5b-71cb58e34975,
#         card:6573461d537dc2002c9ae272,
#         card:6573461e49582e002a8bbd4e,
#         card:6573461ecaa7df003129429d,
#         card:c66bbce5-644c-4d56-9813-45a445965b9b,
#         card:d9e549c4-2088-4f9f-813a-c37f89eeaec4,
#         card:e9e083db-966a-4951-8ce5-6e46e851d9d3 ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_7> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_7" ;
#     rdf:language "en" ;
#     l:Card card:06db7341-1806-433e-b860-3e719da8767c,
#         card:09a029eb-b22f-4a3f-9316-4f5ae8203ee8,
#         card:0fb61114-7182-436d-ad2a-e75bf3072bde,
#         card:11bcf618-7ef2-4d7d-af16-0a03cdea38e5,
#         card:195e8ab9-05ee-45c4-bdd0-40fd14a26cc9,
#         card:2ecb1de9-b1e7-42ad-8a28-0da577de2ce8,
#         card:33f4c8db-ff86-48ce-8fca-363b44a180d2,
#         card:64d914b2-e8e9-42f3-a069-aa3eff956afe,
#         card:6573461d537dc2002c9ae272,
#         card:6573461d7caa6f00243dde93,
#         card:6573461df297f4002acd80df,
#         card:6573461e49582e002a8bbd4e,
#         card:6573461ecaa7df0031294288,
#         card:8ae48c03-2e1e-4f6a-83d8-b7dd6970e8f1,
#         card:a3314227-eda3-43df-908f-6ac789678b68,
#         card:b136e6c3-0677-48b7-812b-c3c679c1c1cc,
#         card:b7485e40-8a14-4a15-b7cb-9a3ae3311639,
#         card:e7fe67c9-11b9-4594-bbc3-0b3f1fd7d5dd,
#         card:fba8e0be-f078-4402-9f89-1fcfcd3a0cb6 ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_8> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_8" ;
#     rdf:language "en" ;
#     l:Card card:09ac5cbd-5a0f-48ed-85d1-13016ba46c49,
#         card:18b2b046-eee2-4742-9dbc-50e9be2511c8,
#         card:2864722a-f2ef-4694-a6a5-cb11ad19499c,
#         card:3f6658b1-52a2-4e38-b7f1-e3e7aaa705a6,
#         card:443c8034-106f-435a-bd42-d23196f9226c,
#         card:53cbded0-1192-43ed-a8fd-da3b297a916f,
#         card:5bada782-3445-4740-9e11-c6b2d7ea532a,
#         card:6573461d537dc2002c9ae272,
#         card:6573461df297f4002acd80df,
#         card:75b5d7a9-3728-4d64-a822-4dedf8e9b7e8,
#         card:7e1bca3a-23c1-4539-9324-32686e937b86,
#         card:88e23af1-9025-4a4f-b571-ec679cd14d0f,
#         card:89948d1d-7de2-497f-8441-7432da11525f,
#         card:9fc600cb-e4dd-4906-9969-979e40829378,
#         card:b96c16d0-7bb6-438a-bbe6-8cf6753683a9,
#         card:d3b8b5fb-8cc0-4f7f-b44c-79cb1cab0b0c ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# <https://data.lettria.com/document/6573456c537dc2002c9ae1eb_document_9> a l:Document ;
#     rdfs:label "6573456c537dc2002c9ae1eb_document_9" ;
#     rdf:language "en" ;
#     l:Card card:03d64f3d-c40d-4e55-8422-633b2e1ccfca,
#         card:118f22a3-1efc-4287-a651-479f017c3692,
#         card:5fc1d946-3283-41f0-84e7-e6ab5da4525e,
#         card:8191d208-8421-4408-bac0-ae7bc96a8ac9,
#         card:89c2bfe4-b882-4fb4-9222-de836d84d188,
#         card:949293e5-fd2c-455f-894c-e017413efe64,
#         card:a5a36bb5-e1e0-43f1-a999-c85a6210835b,
#         card:f037580b-3e6a-4f1c-a6a5-3af438185aa9 ;
#     m:projectId "6573456c537dc2002c9ae1eb" .
#
# info:02b3b9c6-e53f-4486-a7de-8e028a5495cf a owl:ObjectProperty,
#         l:Link ;
#     rdfs:label "Comparison|LIKE" ;
#     d:value card:6573461e7caa6f00243ddeac ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:10|0:12|0:27" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "49:56|62:64|148:154" ;
#     m:temporality "present" ;
#     m:uniqueId "02b3b9c6-e53f-4486-a7de-8e028a5495cf|1702053461.5763779" .
#
# info:059d81b9-419c-460c-94bd-e1a5a8773d96 a owl:ObjectProperty,
#         l:Possessing ;
#     rdfs:label "ownership" ;
#     d:value card:949293e5-fd2c-455f-894c-e017413efe64 ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:7|0:11" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "41:48|60:68" ;
#     m:temporality "present" ;
#     m:uniqueId "059d81b9-419c-460c-94bd-e1a5a8773d96|1702053461.6577854" .
#
# info:0609a8dd-cb0f-4592-9096-9755ffb38cb1 a owl:ObjectProperty,
#         l:Link ;
#     rdfs:label "Manner|WITH" ;
#     d:value card:a3314227-eda3-43df-908f-6ac789678b68 ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:32|0:34|0:36" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "239:247|259:263|268:283" ;
#     m:temporality "present" ;
#     m:uniqueId "0609a8dd-cb0f-4592-9096-9755ffb38cb1|1702053461.6405835" .
#
# info:07290bee-3ebc-4346-96a4-8f9ad59bddc7 a owl:ObjectProperty,
#         l:Link ;
#     rdfs:label "Manner|HOW" ;
#     d:value info:ffb691da-9949-490c-a686-3324b38ac25d ;
#     d:valueType "event" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:4|0:5" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "29:36|37:44" ;
#     m:temporality "present" ;
#     m:uniqueId "07290bee-3ebc-4346-96a4-8f9ad59bddc7|1702053461.5983064" .
#
# info:07753f99-974d-42d1-96d3-4e90820abcaf a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "root|emp id" ;
#     d:value "e-009" ;
#     d:valueType "string" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:extra "{'property_type': 'attribute'}" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "ontology" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:temporality "present" ;
#     m:uniqueId "07753f99-974d-42d1-96d3-4e90820abcaf|1702053461.602643" .
#
# info:0a64b7d4-3fab-47b5-af71-598675985570 a owl:ObjectProperty,
#         l:Link ;
#     rdfs:label "Complement|OF" ;
#     d:value info:ceb3af52-0e1d-4782-9438-ef03664ea818 ;
#     d:valueType "event" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:59|0:60" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "360:367|368:372" ;
#     m:temporality "present" ;
#     m:uniqueId "0a64b7d4-3fab-47b5-af71-598675985570|1702053461.648995" .
#
# info:0b1546e8-99f6-47e6-a966-20cb55be3c9b a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "kind" ;
#     d:value "class" ;
#     d:valueType "string" ;
#     l:Event info:85815deb-1ad0-40e7-a9b7-f0c74674fe5f ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:2" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "12:17" ;
#     m:temporality "present" ;
#     m:uniqueId "0b1546e8-99f6-47e6-a966-20cb55be3c9b|1702053461.6003146" .
#
# info:0d77063d-6eb2-4010-baa5-d4c65d92c605 a owl:ObjectProperty,
#         l:Attribute ;
#     rdfs:label "Caracteristic" ;
#     d:value card:a3c6a144-a568-4388-8005-4ca81d3948e6 ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:5|0:23" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "40:50|126:132" ;
#     m:temporality "present" ;
#     m:uniqueId "0d77063d-6eb2-4010-baa5-d4c65d92c605|1702053461.5820584" .
#
# info:0ddf3288-62d9-4f98-9354-50f5565c1039 a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "root|joined on" ;
#     d:value "0901-01-01t00:00:00" ;
#     d:valueType "string" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:extra "{'property_type': 'attribute'}" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "ontology" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:temporality "present" ;
#     m:uniqueId "0ddf3288-62d9-4f98-9354-50f5565c1039|1702053461.5940802" .
#
# info:10952391-d851-4b61-896a-b13ae6ca55f9 a owl:ObjectProperty,
#         l:Attribute ;
#     rdfs:label "Caracteristic" ;
#     d:value card:09ac5cbd-5a0f-48ed-85d1-13016ba46c49 ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:0|0:1" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "0:4|5:15" ;
#     m:temporality "present" ;
#     m:uniqueId "10952391-d851-4b61-896a-b13ae6ca55f9|1702053461.6479204" .
#
# info:11b242f8-f233-4b3b-b103-1f20d88b0110 a owl:ObjectProperty,
#         l:Link ;
#     rdfs:label "Comparison|LIKE" ;
#     d:value card:31e92222-0fe1-4cc7-879a-a2ce7ff31186 ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "text" ;
#     m:position "0:5|0:6|0:7" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "40:50|51:55|56:60" ;
#     m:temporality "present" ;
#     m:uniqueId "11b242f8-f233-4b3b-b103-1f20d88b0110|1702053461.5821972" .
#
# info:12a7fb91-8df6-4ba7-9b9d-0321a9d04c90 a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "root|joined on" ;
#     d:value "0901-01-01t00:00:00" ;
#     d:valueType "string" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:extra "{'property_type': 'attribute'}" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "ontology" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:temporality "present" ;
#     m:uniqueId "12a7fb91-8df6-4ba7-9b9d-0321a9d04c90|1702053461.59423" .
#
# info:13317eca-ebbe-4646-b56f-0bc57a44a886 a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "root|emp contact" ;
#     d:value "19011700132" ;
#     d:valueType "string" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:extra "{'property_type': 'attribute'}" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "ontology" ;
#     m:position "" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "" ;
#     m:temporality "present" ;
#     m:uniqueId "13317eca-ebbe-4646-b56f-0bc57a44a886|1702053461.6027586" .
#
# info:1454cea0-37a6-4066-976a-a278b4c833f3 a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "kind" ;
#     d:value "class" ;
#     d:valueType "string" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
# ...
#         "[indefinite_things]",
#         "[qualified_things]",
#         "abstract_thing",
#         "best_thing",
#         "entity" ;
#     d:finestCategosens "best_thing" ;
#     d:lemma "essence" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:7" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "41:48" ;
#     m:uniqueId "949293e5-fd2c-455f-894c-e017413efe64|1702053461.5720584" .
#
# card:a7ccbae4-e9eb-4825-aa42-2838f215309d a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|[features]|[manners/practices]|position_(n)" ;
#     d:categosens "[features]",
#         "[manners/practices]",
#         "abstract_thing",
#         "position_(n)" ;
#     d:finestCategosens "position_(n)" ;
#     d:lemma "instance" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation true ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:2" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "16:25" ;
#     m:uniqueId "a7ccbae4-e9eb-4825-aa42-2838f215309d|1702053461.529228" .
#
# info:0a7b30b3-6f8b-4bb6-ac68-0412814dadb1 a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "kind" ;
#     d:value "type" ;
#     d:valueType "string" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:20|0:21" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "148:153|154:159" ;
#     m:temporality "present" ;
#     m:uniqueId "0a7b30b3-6f8b-4bb6-ac68-0412814dadb1|1702053461.6415255" .
#
# info:72099624-f2ca-4d4e-a276-58a05df0a087 a owl:DatatypeProperty,
#         l:Attribute ;
#     rdfs:label "kind" ;
#     d:value "type" ;
#     d:valueType "string" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:44|0:45" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "321:326|327:332" ;
#     m:temporality "present" ;
#     m:uniqueId "72099624-f2ca-4d4e-a276-58a05df0a087|1702053461.642451" .
#
# info:7acff843-55af-40ce-a5f3-e30a0ac713f3 a owl:ObjectProperty,
#         l:Possessing ;
#     rdfs:label "ownership:part" ;
#     d:value card:6573461d537dc2002c9ae272 ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:21|0:22|0:23|0:14|0:18" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "143:154|155:158|159:163|93:97|116:126" ;
#     m:temporality "present" ;
#     m:uniqueId "7acff843-55af-40ce-a5f3-e30a0ac713f3|1702053461.6336064" .
#
# info:d5fbd4d6-0741-4144-8cad-7ea2cb30240c a owl:ObjectProperty,
#         l:Possessing ;
#     rdfs:label "ownership:part" ;
#     d:value card:470b7837-f4b4-4c88-8f5b-71cb58e34975 ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:34|0:36|0:14|0:18" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "230:235|238:242|93:97|116:126" ;
#     m:temporality "present" ;
#     m:uniqueId "d5fbd4d6-0741-4144-8cad-7ea2cb30240c|1702053461.6336617" .
#
# info:fa917f8f-d731-49ad-85ee-7a9f517dea64 a owl:ObjectProperty,
#         l:Possessing ;
#     rdfs:label "ownership:part" ;
#     d:value card:6573461d537dc2002c9ae272 ;
#     d:valueType "card" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:intensity 1e+00 ;
#     m:negation false ;
#     m:origin "understanding" ;
#     m:position "0:12|0:13|0:14|0:18" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "77:88|89:92|93:97|116:126" ;
#     m:temporality "present" ;
#     m:uniqueId "fa917f8f-d731-49ad-85ee-7a9f517dea64|1702053461.6336346" .
#
# card:6573461d7caa6f00243dde93 a owl:Class,
#         l:Card ;
#     d:categopath "root|office" ;
#     d:categosens "office",
#         "root" ;
#     d:finestCategosens "office" ;
#     d:lemma "office" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false,
#         true ;
#     m:position "0:35",
#         "0:6" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "183:189",
#         "37:44" ;
#     m:uniqueId "6573461d7caa6f00243dde93|1702053461.518508",
#         "6573461d7caa6f00243dde93|1702053461.5583968" .
#
# card:6573461e911ed5002428cd6b a owl:Class,
#         l:Card ;
#     l:Attribute info:0a0b87ee-851c-4d1c-9d48-52f2142f87b3,
#         info:465e4caf-08d6-4b8c-aac4-75eb1a72f395,
#         info:4bf13708-4a39-4561-b376-18c7ab49187d,
#         info:aa4d4b3e-c012-457e-992a-336e9054c7fc,
#         info:dcec6928-f112-4eee-9372-0411967358a7 ;
#     d:categopath "root|departments|operations|opcore" ;
#     d:categosens "departments",
#         "opcore",
#         "operations",
#         "root" ;
#     d:finestCategosens "opcore" ;
#     d:lemma "opcore" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false ;
#     m:position "0:26",
#         "0:40|0:42" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "146:152",
#         "217:223|227:237" ;
#     m:uniqueId "6573461e911ed5002428cd6b|1702053461.529255",
#         "6573461e911ed5002428cd6b|1702053461.5336332" .
#
# card:6573461e49582e002a8bbd67 a owl:Class,
#         l:Card ;
#     l:Attribute info:a6892e0e-19e8-4191-9a43-87890ac451c0 ;
#     d:categopath "root|employees|senior" ;
#     d:categosens "employees",
#         "root",
#         "senior" ;
#     d:finestCategosens "senior" ;
#     d:lemma "senior" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false ;
#     m:position "0:10",
#         "0:40",
#         "0:81" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "207:213",
#         "410:416",
#         "61:67" ;
#     m:uniqueId "6573461e49582e002a8bbd67|1702053461.518476",
#         "6573461e49582e002a8bbd67|1702053461.5335534",
#         "6573461e49582e002a8bbd67|1702053461.5445793" .
#
# card:6573461e7caa6f00243ddeac a owl:Class,
#         l:Card ;
#     l:Attribute info:cc3e77ac-699b-427e-9170-df3311d04122 ;
#     d:categopath "root|employees|junior" ;
#     d:categosens "employees",
#         "junior",
#         "root" ;
#     d:finestCategosens "junior" ;
#     d:lemma "junior" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false ;
#     m:position "0:15",
#         "0:27",
#         "0:45" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "148:154",
#         "240:246",
#         "79:85" ;
#     m:uniqueId "6573461e7caa6f00243ddeac|1702053461.5185554",
#         "6573461e7caa6f00243ddeac|1702053461.5335205",
#         "6573461e7caa6f00243ddeac|1702053461.5447762" .
#
# card:6573461e911ed5002428cd4a a owl:Class,
#         l:Card ;
#     l:Attribute info:c74fb60d-7ea1-4cf8-8c02-0adff926b2d4 ;
#     d:categopath "root|employees|intern" ;
#     d:categosens "employees",
#         "intern",
#         "root" ;
#     d:finestCategosens "intern" ;
#     d:lemma "intern" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false ;
#     m:position "0:21",
#         "0:24",
#         "0:25" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "115:121",
#         "117:123",
#         "137:143" ;
#     m:uniqueId "6573461e911ed5002428cd4a|1702053461.5183759",
#         "6573461e911ed5002428cd4a|1702053461.5334525",
#         "6573461e911ed5002428cd4a|1702053461.544937" .
#
# card:6573461ecaa7df0031294288 a owl:Class,
#         l:Card ;
#     l:Attribute info:e83ebfc0-62cc-4f1d-99fe-89679f8610de ;
#     d:categopath "root|departments|marketing" ;
#     d:categosens "departments",
#         "marketing",
#         "root" ;
#     d:finestCategosens "marketing" ;
#     d:lemma "marketing" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false ;
#     m:position "0:25",
#         "0:33",
#         "0:43|0:57|0:66" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "172:181",
#         "185:194",
#         "229:238|290:299|333:342" ;
#     m:uniqueId "6573461ecaa7df0031294288|1702053461.5185237",
#         "6573461ecaa7df0031294288|1702053461.5451999",
#         "6573461ecaa7df0031294288|1702053461.5582433" .
#
# card:6573461ef297f4002acd80fc a owl:Class,
#         l:Card ;
#     l:Attribute info:2750a7e4-1661-4694-8ac7-94ab00885e92 ;
#     d:categopath "root|employees|manager" ;
#     d:categosens "employees",
#         "manager",
#         "root" ;
#     d:finestCategosens "manager" ;
#     d:lemma "manager" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false ;
#     m:position "0:20",
#         "0:31",
#         "0:59" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "163:170",
#         "301:308",
#         "97:104" ;
#     m:uniqueId "6573461ef297f4002acd80fc|1702053461.5185401",
#         "6573461ef297f4002acd80fc|1702053461.533486",
#         "6573461ef297f4002acd80fc|1702053461.5446968" .
#
# card:6573461f7caa6f00243ddee7 a owl:Class,
#         l:Card ;
#     l:Attribute info:570c6e61-b3a7-4075-941d-9006bae41edd ;
#     d:categopath "root|departments|marketing|international" ;
#     d:categosens "departments",
#         "international",
#         "marketing",
#         "root" ;
#     d:finestCategosens "international" ;
#     d:lemma "international" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural false ;
#     m:position "0:25",
#         "0:33",
#         "0:38" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "133:146",
#         "165:178",
#         "202:215" ;
#     m:uniqueId "6573461f7caa6f00243ddee7|1702053461.5183544",
#         "6573461f7caa6f00243ddee7|1702053461.5332577",
#         "6573461f7caa6f00243ddee7|1702053461.544818" .
#
# card:a3314227-eda3-43df-908f-6ac789678b68 a owl:Class,
#         l:Card ;
#     d:categopath "abstract_thing|entity|[activities_(n)]|activity_field" ;
#     d:categosens "[activities_(n)]",
#         "abstract_thing",
#         "activity_field",
#         "entity" ;
#     d:finestCategosens "activity_field" ;
#     d:lemma "sub-department" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Lettria" ;
#     m:plural true ;
#     m:position "0:28|0:36" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "204:219|268:283" ;
#     m:uniqueId "a3314227-eda3-43df-908f-6ac789678b68|1702053461.5585897" .
#
# card:6573461ecaa7df00312942b6 a owl:Class,
#         l:Card ;
#     l:Attribute info:2d90d7a5-d1b1-4fb4-9d0e-8ba5e25d329a,
#         info:2f69384a-69fd-43e7-932e-d38c83bf0c34,
#         info:4d6ec282-c9ba-486d-8182-77a9cf1bf01f,
#         info:4dd1bae9-6e02-47c4-949a-9cb5b894058b,
#         info:6de142aa-44ef-45fc-ac6a-f355f599f436,
#         info:6de3f447-79b9-4fd8-bf21-0d1d8ff69ff9,
#         info:9ea8cf60-241d-4d59-9aeb-3b413806df6e,
#         info:b3acb88f-673e-461d-b2f6-a5584de528fc,
#         info:be5a82a1-7cc3-46c7-ac2e-c6faa94a7ff3,
#         info:c4b020d8-d94d-44bd-bf39-e70f830978e8,
#         info:c9f0dfae-679d-4ab2-bdad-fa61a0db1e1c,
#         info:cb3dc99d-eac0-4fb8-a9d5-4fea4de2f8d6,
#         info:d353b3bd-04b8-4a71-a28e-e4c2d96f4be5,
#         info:d3e4c820-f660-4635-9faf-e509f1d6c43d,
#         info:e6f91ecc-bf1e-46f6-a7eb-3cddc718e280,
#         info:fcd7e31e-0a39-40b6-be6a-53de7debe877 ;
#     d:categopath "root|employees|senior|harry" ;
#     d:categosens "employees",
#         "harry",
#         "root",
#         "senior" ;
#     d:finestCategosens "harry" ;
#     d:lemma "harry" ;
#     l:Link info:ea044097-ce34-4b41-94b2-a3f7af07c9af ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural false ;
#     m:position "0:11",
#         "0:7",
#         "0:9|0:6" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "50:55",
#         "53:58|35:46",
#         "73:78" ;
#     m:uniqueId "6573461ecaa7df00312942b6|1702053461.5294046",
#         "6573461ecaa7df00312942b6|1702053461.5335708",
#         "6573461ecaa7df00312942b6|1702053461.5379832" .
#
# card:6573461df297f4002acd80df a owl:Class,
#         l:Card ;
#     l:Attribute info:1963a6cc-325c-4759-99f4-7d06b42a62fb,
#         info:21acd3c0-f6bb-4aa4-97f3-4ffe168926d0,
#         info:37c75a14-0844-4f7b-ad03-2e516494a8a3,
#         info:95bed0d4-c957-4713-a5a3-c6a360317cb3,
#         info:deb469fe-a177-45bc-94d5-c100b817c3dd ;
#     d:categopath "root|employees" ;
#     d:categosens "employees",
#         "root" ;
#     d:finestCategosens "employees" ;
#     d:lemma "employees" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural true ;
#     m:position "0:14|0:42",
#         "0:15",
#         "0:29",
#         "0:62|0:32|0:51|0:42",
#         "0:64",
#         "0:86|0:50" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "157:166",
#         "322:331",
#         "376:385|202:211|311:320|259:268",
#         "430:439|260:269",
#         "78:87",
#         "96:105|306:315" ;
#     m:uniqueId "6573461df297f4002acd80df|1702053461.5184195",
#         "6573461df297f4002acd80df|1702053461.544653",
#         "6573461df297f4002acd80df|1702053461.544895",
#         "6573461df297f4002acd80df|1702053461.545171",
#         "6573461df297f4002acd80df|1702053461.5583446",
#         "6573461df297f4002acd80df|1702053461.5661716" ;
#     l:Possessing info:4214deda-1e6d-490a-87d5-c5a358995800,
#         info:e6d7a395-8f17-4d79-b328-ddb086da2ecc .
#
# card:6573461e49582e002a8bbd4e a owl:Class,
#         l:Card ;
#     l:Attribute info:b642efa4-6b1b-4fb3-aa26-11b4aa4debe5 ;
#     d:categopath "root|departments|operations" ;
#     d:categosens "departments",
#         "operations",
#         "root" ;
#     d:finestCategosens "operations" ;
#     d:lemma "operations" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural true ;
#     m:position "0:17",
#         "0:33",
#         "0:36|0:15|0:73",
#         "0:37" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "105:115",
#         "190:200|84:94|369:379",
#         "191:201",
#         "248:258" ;
#     m:uniqueId "6573461e49582e002a8bbd4e|1702053461.5184922",
#         "6573461e49582e002a8bbd4e|1702053461.545228",
#         "6573461e49582e002a8bbd4e|1702053461.553109",
#         "6573461e49582e002a8bbd4e|1702053461.5581374" .
#
# card:6573461d537dc2002c9ae272 a owl:Class,
#         l:Card ;
#     l:Attribute info:985135bb-c0c9-442e-b7d7-80a756caa9c1,
#         info:9de58cb7-ebb7-47f7-abcc-a21801796829,
#         info:b2613b97-05b3-4876-bb8f-0e9264a2c4f1,
#         info:c696c0b4-3cb4-4a76-81ef-8aa7df69ccdb,
#         info:cfdee15c-2353-4f91-8898-6f88843d5aad ;
#     d:categopath "root|departments" ;
#     d:categosens "departments",
#         "root" ;
#     d:finestCategosens "departments" ;
#     d:lemma "departments" ;
#     m:creationDate "Friday, December 08, 2023 04:37:41" ;
#     m:negation false ;
#     m:origin "Perso" ;
#     m:plural true ;
#     m:position "0:11|0:22",
#         "0:12",
#         "0:13",
#         "0:21",
#         "0:22|0:71|0:78",
#         "0:27|0:38",
#         "0:8|0:12|0:18" ;
#     m:projectId "6573456c537dc2002c9ae1eb" ;
#     m:purePosition "124:135|356:367|393:404",
#         "143:154",
#         "179:190|246:257",
#         "50:61|79:90|131:142",
#         "65:76",
#         "74:85|135:146",
#         "77:88" ;
#     m:uniqueId "6573461d537dc2002c9ae272|1702053461.5184364",
#         "6573461d537dc2002c9ae272|1702053461.5449617",
#         "6573461d537dc2002c9ae272|1702053461.553242",
#         "6573461d537dc2002c9ae272|1702053461.553284",
#         "6573461d537dc2002c9ae272|1702053461.5533254",
#         "6573461d537dc2002c9ae272|1702053461.5585346",
#         "6573461d537dc2002c9ae272|1702053461.566206" ;
#     l:Possessing info:49eeb304-60ef-4c84-a129-0fdf3673697e,
#         info:bc6498ec-f21e-4e43-a888-81be0e283e9e .
